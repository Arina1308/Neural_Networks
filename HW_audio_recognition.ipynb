# %% [markdown]
# <center><img src="https://github.com/hse-ds/iad-applied-ds/blob/master/2021/hw/hw1/img/logo_hse.png?raw=1" width="1000"></center>
#
# <h1><center>Прикладные задачи анализа данных</center></h1>
# <h2><center>Домашнее задание 2: Deep learning для обработки звука</center></h2>

# %% [markdown]
# # Введение
#
# В этом задании Вы поработаете и разберетесь в деталях с форматами представления аудиоданных в задачах глубинного обучения, а так же напишете несколько моделей для классификации аудиозаписей.
#
# В процессе выполнения Вы познакомитесь:
# * С алгоритмом построения Мел-спектрограммы.
# * Рекуррентными и сверточными классификаторами аудиоданных.
# * Алгоритмом аугментации аудиоданных SpecAugment.

# %%
! pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html

# чтобы cuda не ломалась
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.8.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.8.0%2Bcu111-cp37-cp37m-linux_x86_64.whl (1982.2MB)
#      |█████████████▌                  | 834.1MB 1.6MB/s eta 0:12:08tcmalloc: large alloc 1147494400 bytes == 0x56037b27a000 @  0x7fb026cda615 0x5603418b706c 0x560341996eba 0x5603418b9e8d 0x5603419ab99d 0x56034192dfe9 0x560341928b0e 0x5603418bb77a 0x56034192de50 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341a2e431 0x56034198f049 0x5603418f9c84 0x5603418ba8e9 0x56034192eade 0x5603418bb69a 0x560341929a45 0x560341928e0d 0x5603418bb77a 0x560341929a45 0x5603418bb69a 0x560341929a45
#      |█████████████████               | 1055.7MB 1.3MB/s eta 0:11:39tcmalloc: large alloc 1434370048 bytes == 0x5603bf8d0000 @  0x7fb026cda615 0x5603418b706c 0x560341996eba 0x5603418b9e8d 0x5603419ab99d 0x56034192dfe9 0x560341928b0e 0x5603418bb77a 0x56034192de50 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341a2e431 0x56034198f049 0x5603418f9c84 0x5603418ba8e9 0x56034192eade 0x5603418bb69a 0x560341929a45 0x560341928e0d 0x5603418bb77a 0x560341929a45 0x5603418bb69a 0x560341929a45
#      |█████████████████████▋          | 1336.2MB 1.2MB/s eta 0:08:49tcmalloc: large alloc 1792966656 bytes == 0x560344702000 @  0x7fb026cda615 0x5603418b706c 0x560341996eba 0x5603418b9e8d 0x5603419ab99d 0x56034192dfe9 0x560341928b0e 0x5603418bb77a 0x56034192de50 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341a2e431 0x56034198f049 0x5603418f9c84 0x5603418ba8e9 0x56034192eade 0x5603418bb69a 0x560341929a45 0x560341928e0d 0x5603418bb77a 0x560341929a45 0x5603418bb69a 0x560341929a45
#      |███████████████████████████▎    | 1691.1MB 1.3MB/s eta 0:03:51tcmalloc: large alloc 2241208320 bytes == 0x5603af4ea000 @  0x7fb026cda615 0x5603418b706c 0x560341996eba 0x5603418b9e8d 0x5603419ab99d 0x56034192dfe9 0x560341928b0e 0x5603418bb77a 0x56034192de50 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341929ee2 0x5603419ac7c6 0x560341a2e431 0x56034198f049 0x5603418f9c84 0x5603418ba8e9 0x56034192eade 0x5603418bb69a 0x560341929a45 0x560341928e0d 0x5603418bb77a 0x560341929a45 0x5603418bb69a 0x560341929a45
#      |████████████████████████████████| 1982.2MB 1.1MB/s eta 0:00:01tcmalloc: large alloc 1982251008 bytes == 0x560434e4c000 @  0x7fb026cd91e7 0x5603418ed017 0x5603418b706c 0x560341996eba 0x5603418b9e8d 0x5603419ab99d 0x56034192dfe9 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x5603418bb69a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x560341928b0e
# tcmalloc: large alloc 2477817856 bytes == 0x5604ab0b8000 @  0x7fb026cda615 0x5603418b706c 0x560341996eba 0x5603418b9e8d 0x5603419ab99d 0x56034192dfe9 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x560341929c9e 0x5603418bb69a 0x560341929c9e 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x560341928b0e 0x5603418bb77a 0x56034192a86a 0x560341928b0e 0x5603418bbe11
#      |████████████████████████████████| 1982.2MB 4.0kB/s
# Collecting torchvision==0.9.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.9.0%2Bcu111-cp37-cp37m-linux_x86_64.whl (17.6MB)
#      |████████████████████████████████| 17.6MB 200kB/s
# Collecting torchaudio==0.8.0
#   Downloading https://files.pythonhosted.org/packages/18/9a/4e2e6dbde627ffb8a6d1d4ebc4683edecad1c08099969f1d7760d92175ff/torchaudio-0.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 7.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0+cu111) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0+cu111) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.9.0+cu111) (7.1.2)
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.8.0+cu111 which is incompatible.
# Installing collected packages: torch, torchvision, torchaudio
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# Successfully installed torch-1.8.0+cu111 torchaudio-0.8.0 torchvision-0.9.0+cu111

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Colab_Notebooks/HW2_dataset.zip -d ./data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/urbansound8k/data/712.wav
#   inflating: ./data/urbansound8k/data/1286.wav
#   inflating: ./data/urbansound8k/data/7768.wav
#   inflating: ./data/urbansound8k/data/855.wav
#   inflating: ./data/urbansound8k/data/1319.wav
#   inflating: ./data/urbansound8k/data/15.wav
#   inflating: ./data/urbansound8k/data/2610.wav
#   inflating: ./data/urbansound8k/data/3268.wav
#   inflating: ./data/urbansound8k/data/5619.wav
#   inflating: ./data/urbansound8k/data/6310.wav
#   inflating: ./data/urbansound8k/data/6304.wav
#   inflating: ./data/urbansound8k/data/4513.wav
#   inflating: ./data/urbansound8k/data/2162.wav
#   inflating: ./data/urbansound8k/data/2604.wav
#   inflating: ./data/urbansound8k/data/841.wav
#   inflating: ./data/urbansound8k/data/699.wav
#   inflating: ./data/urbansound8k/data/6462.wav
#   inflating: ./data/urbansound8k/data/869.wav
#   inflating: ./data/urbansound8k/data/8467.wav
#   inflating: ./data/urbansound8k/data/7754.wav
#   inflating: ./data/urbansound8k/data/7032.wav
#   inflating: ./data/urbansound8k/data/3254.wav
#   inflating: ./data/urbansound8k/data/5625.wav
#   inflating: ./data/urbansound8k/data/3240.wav
#   inflating: ./data/urbansound8k/data/5631.wav
#   inflating: ./data/urbansound8k/data/6338.wav
#   inflating: ./data/urbansound8k/data/8315.wav
#   inflating: ./data/urbansound8k/data/7026.wav
#   inflating: ./data/urbansound8k/data/8473.wav
#   inflating: ./data/urbansound8k/data/7740.wav
#   inflating: ./data/urbansound8k/data/7998.wav
#   inflating: ./data/urbansound8k/data/5157.wav
#   inflating: ./data/urbansound8k/data/3526.wav
#   inflating: ./data/urbansound8k/data/4249.wav
#   inflating: ./data/urbansound8k/data/8498.wav
#   inflating: ./data/urbansound8k/data/896.wav
#   inflating: ./data/urbansound8k/data/128.wav
#   inflating: ./data/urbansound8k/data/5802.wav
#   inflating: ./data/urbansound8k/data/5816.wav
#   inflating: ./data/urbansound8k/data/882.wav
#   inflating: ./data/urbansound8k/data/2837.wav
#   inflating: ./data/urbansound8k/data/5180.wav
#   inflating: ./data/urbansound8k/data/3297.wav
#   inflating: ./data/urbansound8k/data/1480.wav
#   inflating: ./data/urbansound8k/data/114.wav
#   inflating: ./data/urbansound8k/data/100.wav
#   inflating: ./data/urbansound8k/data/3283.wav
#   inflating: ./data/urbansound8k/data/666.wav
#   inflating: ./data/urbansound8k/data/7783.wav
#   inflating: ./data/urbansound8k/data/4705.wav
#   inflating: ./data/urbansound8k/data/2412.wav
#   inflating: ./data/urbansound8k/data/6674.wav
#   inflating: ./data/urbansound8k/data/8659.wav
#   inflating: ./data/urbansound8k/data/6660.wav
#   inflating: ./data/urbansound8k/data/4077.wav
#   inflating: ./data/urbansound8k/data/3718.wav
#   inflating: ./data/urbansound8k/data/5369.wav
#   inflating: ./data/urbansound8k/data/2360.wav
#   inflating: ./data/urbansound8k/data/7218.wav
#   inflating: ./data/urbansound8k/data/1669.wav
#   inflating: ./data/urbansound8k/data/5427.wav
#   inflating: ./data/urbansound8k/data/3056.wav
#   inflating: ./data/urbansound8k/data/4739.wav
#   inflating: ./data/urbansound8k/data/8103.wav
#   inflating: ./data/urbansound8k/data/1899.wav
#   inflating: ./data/urbansound8k/data/6648.wav
#   inflating: ./data/urbansound8k/data/7556.wav
#   inflating: ./data/urbansound8k/data/8665.wav
#   inflating: ./data/urbansound8k/data/3724.wav
#   inflating: ./data/urbansound8k/data/1133.wav
#   inflating: ./data/urbansound8k/data/7542.wav
#   inflating: ./data/urbansound8k/data/7224.wav
#   inflating: ./data/urbansound8k/data/5433.wav
#   inflating: ./data/urbansound8k/data/3042.wav
#   inflating: ./data/urbansound8k/data/1866.wav
#   inflating: ./data/urbansound8k/data/3903.wav
#   inflating: ./data/urbansound8k/data/1872.wav
#   inflating: ./data/urbansound8k/data/316.wav
#   inflating: ./data/urbansound8k/data/3095.wav
#   inflating: ./data/urbansound8k/data/5382.wav
#   inflating: ./data/urbansound8k/data/6853.wav
#   inflating: ./data/urbansound8k/data/7595.wav
#   inflating: ./data/urbansound8k/data/470.wav
#   inflating: ./data/urbansound8k/data/6847.wav
#   inflating: ./data/urbansound8k/data/7581.wav
#   inflating: ./data/urbansound8k/data/464.wav
#   inflating: ./data/urbansound8k/data/3081.wav
#   inflating: ./data/urbansound8k/data/4089.wav
#   inflating: ./data/urbansound8k/data/5397.wav
#   inflating: ./data/urbansound8k/data/7580.wav
#   inflating: ./data/urbansound8k/data/6846.wav
#   inflating: ./data/urbansound8k/data/303.wav
#   inflating: ./data/urbansound8k/data/1697.wav
#   inflating: ./data/urbansound8k/data/4937.wav
#   inflating: ./data/urbansound8k/data/4923.wav
#   inflating: ./data/urbansound8k/data/3094.wav
#   inflating: ./data/urbansound8k/data/317.wav
#   inflating: ./data/urbansound8k/data/471.wav
#   inflating: ./data/urbansound8k/data/6852.wav
#   inflating: ./data/urbansound8k/data/459.wav
#   inflating: ./data/urbansound8k/data/3902.wav
#   inflating: ./data/urbansound8k/data/1873.wav
#   inflating: ./data/urbansound8k/data/1867.wav
#   inflating: ./data/urbansound8k/data/3916.wav
#   inflating: ./data/urbansound8k/data/8670.wav
#   inflating: ./data/urbansound8k/data/7543.wav
#   inflating: ./data/urbansound8k/data/3725.wav
#   inflating: ./data/urbansound8k/data/5432.wav
#   inflating: ./data/urbansound8k/data/1640.wav
#   inflating: ./data/urbansound8k/data/1898.wav
#   inflating: ./data/urbansound8k/data/7231.wav
#   inflating: ./data/urbansound8k/data/2349.wav
#   inflating: ./data/urbansound8k/data/5426.wav
#   inflating: ./data/urbansound8k/data/5340.wav
#   inflating: ./data/urbansound8k/data/3731.wav
#   inflating: ./data/urbansound8k/data/8664.wav
#   inflating: ./data/urbansound8k/data/6891.wav
#   inflating: ./data/urbansound8k/data/1126.wav
#   inflating: ./data/urbansound8k/data/6649.wav
#   inflating: ./data/urbansound8k/data/3719.wav
#   inflating: ./data/urbansound8k/data/4076.wav
#   inflating: ./data/urbansound8k/data/6661.wav
#   inflating: ./data/urbansound8k/data/6107.wav
#   inflating: ./data/urbansound8k/data/4704.wav
#   inflating: ./data/urbansound8k/data/8658.wav
#   inflating: ./data/urbansound8k/data/2413.wav
#   inflating: ./data/urbansound8k/data/4062.wav
#   inflating: ./data/urbansound8k/data/101.wav
#   inflating: ./data/urbansound8k/data/5195.wav
#   inflating: ./data/urbansound8k/data/5181.wav
#   inflating: ./data/urbansound8k/data/2836.wav
#   inflating: ./data/urbansound8k/data/7796.wav
#   inflating: ./data/urbansound8k/data/673.wav
#   inflating: ./data/urbansound8k/data/1481.wav
#   inflating: ./data/urbansound8k/data/3296.wav
#   inflating: ./data/urbansound8k/data/2188.wav
#   inflating: ./data/urbansound8k/data/5817.wav
#   inflating: ./data/urbansound8k/data/883.wav
#   inflating: ./data/urbansound8k/data/7966.wav
#   inflating: ./data/urbansound8k/data/8499.wav
#   inflating: ./data/urbansound8k/data/7027.wav
#   inflating: ./data/urbansound8k/data/8314.wav
#   inflating: ./data/urbansound8k/data/6339.wav
#   inflating: ./data/urbansound8k/data/4248.wav
#   inflating: ./data/urbansound8k/data/2639.wav
#   inflating: ./data/urbansound8k/data/7999.wav
#   inflating: ./data/urbansound8k/data/1330.wav
#   inflating: ./data/urbansound8k/data/8472.wav
#   inflating: ./data/urbansound8k/data/868.wav
#   inflating: ./data/urbansound8k/data/8466.wav
#   inflating: ./data/urbansound8k/data/3533.wav
#   inflating: ./data/urbansound8k/data/5142.wav
#   inflating: ./data/urbansound8k/data/5624.wav
#   inflating: ./data/urbansound8k/data/8300.wav
#   inflating: ./data/urbansound8k/data/2163.wav
#   inflating: ./data/urbansound8k/data/6305.wav
#   inflating: ./data/urbansound8k/data/6463.wav
#   inflating: ./data/urbansound8k/data/698.wav
#   inflating: ./data/urbansound8k/data/840.wav
#   inflating: ./data/urbansound8k/data/4274.wav
#   inflating: ./data/urbansound8k/data/2605.wav
#   inflating: ./data/urbansound8k/data/4260.wav
#   inflating: ./data/urbansound8k/data/6477.wav
#   inflating: ./data/urbansound8k/data/1318.wav
#   inflating: ./data/urbansound8k/data/854.wav
#   inflating: ./data/urbansound8k/data/7769.wav
#   inflating: ./data/urbansound8k/data/6311.wav
#   inflating: ./data/urbansound8k/data/4506.wav
#   inflating: ./data/urbansound8k/data/4499.wav
#   inflating: ./data/urbansound8k/data/7190.wav
#   inflating: ./data/urbansound8k/data/1287.wav
#   inflating: ./data/urbansound8k/data/713.wav
#   inflating: ./data/urbansound8k/data/2956.wav
#   inflating: ./data/urbansound8k/data/2942.wav
#   inflating: ./data/urbansound8k/data/5963.wav
#   inflating: ./data/urbansound8k/data/7806.wav
#   inflating: ./data/urbansound8k/data/5977.wav
#   inflating: ./data/urbansound8k/data/7153.wav
#   inflating: ./data/urbansound8k/data/8260.wav
#   inflating: ./data/urbansound8k/data/5744.wav
#   inflating: ./data/urbansound8k/data/5022.wav
#   inflating: ./data/urbansound8k/data/3453.wav
#   inflating: ./data/urbansound8k/data/2995.wav
#   inflating: ./data/urbansound8k/data/1244.wav
#   inflating: ./data/urbansound8k/data/8512.wav
#   inflating: ./data/urbansound8k/data/4328.wav
#   inflating: ./data/urbansound8k/data/3321.wav
#   inflating: ./data/urbansound8k/data/5988.wav
#   inflating: ./data/urbansound8k/data/5750.wav
#   inflating: ./data/urbansound8k/data/6259.wav
#   inflating: ./data/urbansound8k/data/1536.wav
#   inflating: ./data/urbansound8k/data/8274.wav
#   inflating: ./data/urbansound8k/data/2017.wav
#   inflating: ./data/urbansound8k/data/5778.wav
#   inflating: ./data/urbansound8k/data/6271.wav
#   inflating: ./data/urbansound8k/data/7609.wav
#   inflating: ./data/urbansound8k/data/1278.wav
#   inflating: ./data/urbansound8k/data/6517.wav
#   inflating: ./data/urbansound8k/data/2771.wav
#   inflating: ./data/urbansound8k/data/2765.wav
#   inflating: ./data/urbansound8k/data/4314.wav
#   inflating: ./data/urbansound8k/data/6265.wav
#   inflating: ./data/urbansound8k/data/4472.wav
#   inflating: ./data/urbansound8k/data/6932.wav
#   inflating: ./data/urbansound8k/data/511.wav
#   inflating: ./data/urbansound8k/data/1085.wav
#   inflating: ./data/urbansound8k/data/277.wav
#   inflating: ./data/urbansound8k/data/7392.wav
#   inflating: ./data/urbansound8k/data/5585.wav
#   inflating: ./data/urbansound8k/data/4843.wav
#   inflating: ./data/urbansound8k/data/4857.wav
#   inflating: ./data/urbansound8k/data/263.wav
#   inflating: ./data/urbansound8k/data/6098.wav
#   inflating: ./data/urbansound8k/data/7386.wav
#   inflating: ./data/urbansound8k/data/6926.wav
#   inflating: ./data/urbansound8k/data/1091.wav
#   inflating: ./data/urbansound8k/data/2598.wav
#   inflating: ./data/urbansound8k/data/3686.wav
#   inflating: ./data/urbansound8k/data/1913.wav
#   inflating: ./data/urbansound8k/data/6729.wav
#   inflating: ./data/urbansound8k/data/8704.wav
#   inflating: ./data/urbansound8k/data/7437.wav
#   inflating: ./data/urbansound8k/data/3889.wav
#   inflating: ./data/urbansound8k/data/5546.wav
#   inflating: ./data/urbansound8k/data/4880.wav
#   inflating: ./data/urbansound8k/data/2229.wav
#   inflating: ./data/urbansound8k/data/4658.wav
#   inflating: ./data/urbansound8k/data/8062.wav
#   inflating: ./data/urbansound8k/data/1720.wav
#   inflating: ./data/urbansound8k/data/8076.wav
#   inflating: ./data/urbansound8k/data/7345.wav
#   inflating: ./data/urbansound8k/data/1734.wav
#   inflating: ./data/urbansound8k/data/4894.wav
#   inflating: ./data/urbansound8k/data/3123.wav
#   inflating: ./data/urbansound8k/data/3645.wav
#   inflating: ./data/urbansound8k/data/5234.wav
#   inflating: ./data/urbansound8k/data/1052.wav
#   inflating: ./data/urbansound8k/data/8710.wav
#   inflating: ./data/urbansound8k/data/7423.wav
#   inflating: ./data/urbansound8k/data/4102.wav
#   inflating: ./data/urbansound8k/data/2573.wav
#   inflating: ./data/urbansound8k/data/6715.wav
#   inflating: ./data/urbansound8k/data/288.wav
#   inflating: ./data/urbansound8k/data/2201.wav
#   inflating: ./data/urbansound8k/data/7379.wav
#   inflating: ./data/urbansound8k/data/1708.wav
#   inflating: ./data/urbansound8k/data/3679.wav
#   inflating: ./data/urbansound8k/data/2567.wav
#   inflating: ./data/urbansound8k/data/8714.wav
#   inflating: ./data/urbansound8k/data/6739.wav
#   inflating: ./data/urbansound8k/data/1056.wav
#   inflating: ./data/urbansound8k/data/3127.wav
#   inflating: ./data/urbansound8k/data/4648.wav
#   inflating: ./data/urbansound8k/data/5556.wav
#   inflating: ./data/urbansound8k/data/4890.wav
#   inflating: ./data/urbansound8k/data/1730.wav
#   inflating: ./data/urbansound8k/data/8072.wav
#   inflating: ./data/urbansound8k/data/1724.wav
#   inflating: ./data/urbansound8k/data/3133.wav
#   inflating: ./data/urbansound8k/data/5542.wav
#   inflating: ./data/urbansound8k/data/4884.wav
#   inflating: ./data/urbansound8k/data/1042.wav
#   inflating: ./data/urbansound8k/data/8728.wav
#   inflating: ./data/urbansound8k/data/6063.wav
#   inflating: ./data/urbansound8k/data/4674.wav
#   inflating: ./data/urbansound8k/data/2205.wav
#   inflating: ./data/urbansound8k/data/1718.wav
#   inflating: ./data/urbansound8k/data/6077.wav
#   inflating: ./data/urbansound8k/data/7369.wav
#   inflating: ./data/urbansound8k/data/2577.wav
#   inflating: ./data/urbansound8k/data/5218.wav
#   inflating: ./data/urbansound8k/data/4106.wav
#   inflating: ./data/urbansound8k/data/3669.wav
#   inflating: ./data/urbansound8k/data/3682.wav
#   inflating: ./data/urbansound8k/data/501.wav
#   inflating: ./data/urbansound8k/data/6922.wav
#   inflating: ./data/urbansound8k/data/7382.wav
#   inflating: ./data/urbansound8k/data/4853.wav
#   inflating: ./data/urbansound8k/data/4847.wav
#   inflating: ./data/urbansound8k/data/6088.wav
#   inflating: ./data/urbansound8k/data/515.wav
#   inflating: ./data/urbansound8k/data/3696.wav
#   inflating: ./data/urbansound8k/data/2588.wav
#   inflating: ./data/urbansound8k/data/3866.wav
#   inflating: ./data/urbansound8k/data/1917.wav
#   inflating: ./data/urbansound8k/data/8099.wav
#   inflating: ./data/urbansound8k/data/8270.wav
#   inflating: ./data/urbansound8k/data/7143.wav
#   inflating: ./data/urbansound8k/data/1532.wav
#   inflating: ./data/urbansound8k/data/3325.wav
#   inflating: ./data/urbansound8k/data/3443.wav
#   inflating: ./data/urbansound8k/data/5032.wav
#   inflating: ./data/urbansound8k/data/7625.wav
#   inflating: ./data/urbansound8k/data/1240.wav
#   inflating: ./data/urbansound8k/data/8502.wav
#   inflating: ./data/urbansound8k/data/7631.wav
#   inflating: ./data/urbansound8k/data/4338.wav
#   inflating: ./data/urbansound8k/data/2991.wav
#   inflating: ./data/urbansound8k/data/5740.wav
#   inflating: ./data/urbansound8k/data/3331.wav
#   inflating: ./data/urbansound8k/data/8264.wav
#   inflating: ./data/urbansound8k/data/7157.wav
#   inflating: ./data/urbansound8k/data/6249.wav
#   inflating: ./data/urbansound8k/data/5768.wav
#   inflating: ./data/urbansound8k/data/4476.wav
#   inflating: ./data/urbansound8k/data/3319.wav
#   inflating: ./data/urbansound8k/data/6507.wav
#   inflating: ./data/urbansound8k/data/7619.wav
#   inflating: ./data/urbansound8k/data/2775.wav
#   inflating: ./data/urbansound8k/data/930.wav
#   inflating: ./data/urbansound8k/data/8258.wav
#   inflating: ./data/urbansound8k/data/2013.wav
#   inflating: ./data/urbansound8k/data/4462.wav
#   inflating: ./data/urbansound8k/data/7180.wav
#   inflating: ./data/urbansound8k/data/1297.wav
#   inflating: ./data/urbansound8k/data/703.wav
#   inflating: ./data/urbansound8k/data/3480.wav
#   inflating: ./data/urbansound8k/data/2946.wav
#   inflating: ./data/urbansound8k/data/717.wav
#   inflating: ./data/urbansound8k/data/7194.wav
#   inflating: ./data/urbansound8k/data/5783.wav
#   inflating: ./data/urbansound8k/data/7802.wav
#   inflating: ./data/urbansound8k/data/1446.wav
#   inflating: ./data/urbansound8k/data/6329.wav
#   inflating: ./data/urbansound8k/data/5146.wav
#   inflating: ./data/urbansound8k/data/3537.wav
#   inflating: ./data/urbansound8k/data/8462.wav
#   inflating: ./data/urbansound8k/data/7751.wav
#   inflating: ./data/urbansound8k/data/7989.wav
#   inflating: ./data/urbansound8k/data/878.wav
#   inflating: ./data/urbansound8k/data/8476.wav
#   inflating: ./data/urbansound8k/data/7745.wav
#   inflating: ./data/urbansound8k/data/38.wav
#   inflating: ./data/urbansound8k/data/1334.wav
#   inflating: ./data/urbansound8k/data/3523.wav
#   inflating: ./data/urbansound8k/data/5634.wav
#   inflating: ./data/urbansound8k/data/1452.wav
#   inflating: ./data/urbansound8k/data/8310.wav
#   inflating: ./data/urbansound8k/data/4502.wav
#   inflating: ./data/urbansound8k/data/2173.wav
#   inflating: ./data/urbansound8k/data/8338.wav
#   inflating: ./data/urbansound8k/data/850.wav
#   inflating: ./data/urbansound8k/data/6473.wav
#   inflating: ./data/urbansound8k/data/10.wav
#   inflating: ./data/urbansound8k/data/688.wav
#   inflating: ./data/urbansound8k/data/2601.wav
#   inflating: ./data/urbansound8k/data/7779.wav
#   inflating: ./data/urbansound8k/data/844.wav
#   inflating: ./data/urbansound8k/data/6467.wav
#   inflating: ./data/urbansound8k/data/1308.wav
#   inflating: ./data/urbansound8k/data/3279.wav
#   inflating: ./data/urbansound8k/data/3292.wav
#   inflating: ./data/urbansound8k/data/1485.wav
#   inflating: ./data/urbansound8k/data/677.wav
#   inflating: ./data/urbansound8k/data/7792.wav
#   inflating: ./data/urbansound8k/data/2832.wav
#   inflating: ./data/urbansound8k/data/5191.wav
#   inflating: ./data/urbansound8k/data/6498.wav
#   inflating: ./data/urbansound8k/data/663.wav
#   inflating: ./data/urbansound8k/data/105.wav
#   inflating: ./data/urbansound8k/data/1491.wav
#   inflating: ./data/urbansound8k/data/2198.wav
#   inflating: ./data/urbansound8k/data/3286.wav
#   inflating: ./data/urbansound8k/data/7976.wav
#   inflating: ./data/urbansound8k/data/893.wav
#   inflating: ./data/urbansound8k/data/887.wav
#   inflating: ./data/urbansound8k/data/5813.wav
#   inflating: ./data/urbansound8k/data/139.wav
#   inflating: ./data/urbansound8k/data/7553.wav
#   inflating: ./data/urbansound8k/data/8660.wav
#   inflating: ./data/urbansound8k/data/6895.wav
#   inflating: ./data/urbansound8k/data/3735.wav
#   inflating: ./data/urbansound8k/data/5344.wav
#   inflating: ./data/urbansound8k/data/7235.wav
#   inflating: ./data/urbansound8k/data/8106.wav
#   inflating: ./data/urbansound8k/data/7221.wav
#   inflating: ./data/urbansound8k/data/5436.wav
#   inflating: ./data/urbansound8k/data/4728.wav
#   inflating: ./data/urbansound8k/data/3721.wav
#   inflating: ./data/urbansound8k/data/5350.wav
#   inflating: ./data/urbansound8k/data/6659.wav
#   inflating: ./data/urbansound8k/data/7547.wav
#   inflating: ./data/urbansound8k/data/6881.wav
#   inflating: ./data/urbansound8k/data/3709.wav
#   inflating: ./data/urbansound8k/data/4066.wav
#   inflating: ./data/urbansound8k/data/5378.wav
#   inflating: ./data/urbansound8k/data/6671.wav
#   inflating: ./data/urbansound8k/data/6117.wav
#   inflating: ./data/urbansound8k/data/1678.wav
#   inflating: ./data/urbansound8k/data/2371.wav
#   inflating: ./data/urbansound8k/data/4714.wav
#   inflating: ./data/urbansound8k/data/6103.wav
#   inflating: ./data/urbansound8k/data/6665.wav
#   inflating: ./data/urbansound8k/data/2403.wav
#   inflating: ./data/urbansound8k/data/6856.wav
#   inflating: ./data/urbansound8k/data/475.wav
#   inflating: ./data/urbansound8k/data/313.wav
#   inflating: ./data/urbansound8k/data/1687.wav
#   inflating: ./data/urbansound8k/data/4927.wav
#   inflating: ./data/urbansound8k/data/307.wav
#   inflating: ./data/urbansound8k/data/7584.wav
#   inflating: ./data/urbansound8k/data/461.wav
#   inflating: ./data/urbansound8k/data/449.wav
#   inflating: ./data/urbansound8k/data/1863.wav
#   inflating: ./data/urbansound8k/data/1877.wav
#   inflating: ./data/urbansound8k/data/3906.wav
#   inflating: ./data/urbansound8k/data/1876.wav
#   inflating: ./data/urbansound8k/data/306.wav
#   inflating: ./data/urbansound8k/data/3085.wav
#   inflating: ./data/urbansound8k/data/7585.wav
#   inflating: ./data/urbansound8k/data/474.wav
#   inflating: ./data/urbansound8k/data/6857.wav
#   inflating: ./data/urbansound8k/data/4926.wav
#   inflating: ./data/urbansound8k/data/3091.wav
#   inflating: ./data/urbansound8k/data/1686.wav
#   inflating: ./data/urbansound8k/data/312.wav
#   inflating: ./data/urbansound8k/data/4715.wav
#   inflating: ./data/urbansound8k/data/2364.wav
#   inflating: ./data/urbansound8k/data/2402.wav
#   inflating: ./data/urbansound8k/data/4073.wav
#   inflating: ./data/urbansound8k/data/8649.wav
#   inflating: ./data/urbansound8k/data/6664.wav
#   inflating: ./data/urbansound8k/data/2416.wav
#   inflating: ./data/urbansound8k/data/4067.wav
#   inflating: ./data/urbansound8k/data/3708.wav
#   inflating: ./data/urbansound8k/data/1679.wav
#   inflating: ./data/urbansound8k/data/6116.wav
#   inflating: ./data/urbansound8k/data/3046.wav
#   inflating: ./data/urbansound8k/data/4729.wav
#   inflating: ./data/urbansound8k/data/5437.wav
#   inflating: ./data/urbansound8k/data/2358.wav
#   inflating: ./data/urbansound8k/data/1651.wav
#   inflating: ./data/urbansound8k/data/1889.wav
#   inflating: ./data/urbansound8k/data/6880.wav
#   inflating: ./data/urbansound8k/data/8675.wav
#   inflating: ./data/urbansound8k/data/1137.wav
#   inflating: ./data/urbansound8k/data/5351.wav
#   inflating: ./data/urbansound8k/data/5345.wav
#   inflating: ./data/urbansound8k/data/3734.wav
#   inflating: ./data/urbansound8k/data/7552.wav
#   inflating: ./data/urbansound8k/data/3052.wav
#   inflating: ./data/urbansound8k/data/5423.wav
#   inflating: ./data/urbansound8k/data/886.wav
#   inflating: ./data/urbansound8k/data/7963.wav
#   inflating: ./data/urbansound8k/data/138.wav
#   inflating: ./data/urbansound8k/data/5806.wav
#   inflating: ./data/urbansound8k/data/892.wav
#   inflating: ./data/urbansound8k/data/7977.wav
#   inflating: ./data/urbansound8k/data/7787.wav
#   inflating: ./data/urbansound8k/data/662.wav
#   inflating: ./data/urbansound8k/data/5190.wav
#   inflating: ./data/urbansound8k/data/2199.wav
#   inflating: ./data/urbansound8k/data/104.wav
#   inflating: ./data/urbansound8k/data/3293.wav
#   inflating: ./data/urbansound8k/data/676.wav
#   inflating: ./data/urbansound8k/data/6466.wav
#   inflating: ./data/urbansound8k/data/845.wav
#   inflating: ./data/urbansound8k/data/2600.wav
#   inflating: ./data/urbansound8k/data/5609.wav
#   inflating: ./data/urbansound8k/data/3278.wav
#   inflating: ./data/urbansound8k/data/6300.wav
#   inflating: ./data/urbansound8k/data/6314.wav
#   inflating: ./data/urbansound8k/data/4503.wav
#   inflating: ./data/urbansound8k/data/4265.wav
#   inflating: ./data/urbansound8k/data/2614.wav
#   inflating: ./data/urbansound8k/data/689.wav
#   inflating: ./data/urbansound8k/data/11.wav
#   inflating: ./data/urbansound8k/data/851.wav
#   inflating: ./data/urbansound8k/data/3522.wav
#   inflating: ./data/urbansound8k/data/1335.wav
#   inflating: ./data/urbansound8k/data/7744.wav
#   inflating: ./data/urbansound8k/data/8477.wav
#   inflating: ./data/urbansound8k/data/7022.wav
#   inflating: ./data/urbansound8k/data/8311.wav
#   inflating: ./data/urbansound8k/data/5635.wav
#   inflating: ./data/urbansound8k/data/3244.wav
#   inflating: ./data/urbansound8k/data/3250.wav
#   inflating: ./data/urbansound8k/data/7036.wav
#   inflating: ./data/urbansound8k/data/8305.wav
#   inflating: ./data/urbansound8k/data/6328.wav
#   inflating: ./data/urbansound8k/data/1447.wav
#   inflating: ./data/urbansound8k/data/7988.wav
#   inflating: ./data/urbansound8k/data/1321.wav
#   inflating: ./data/urbansound8k/data/7750.wav
#   inflating: ./data/urbansound8k/data/3536.wav
#   inflating: ./data/urbansound8k/data/5147.wav
#   inflating: ./data/urbansound8k/data/7817.wav
#   inflating: ./data/urbansound8k/data/5966.wav
#   inflating: ./data/urbansound8k/data/716.wav
#   inflating: ./data/urbansound8k/data/3495.wav
#   inflating: ./data/urbansound8k/data/7195.wav
#   inflating: ./data/urbansound8k/data/5796.wav
#   inflating: ./data/urbansound8k/data/3481.wav
#   inflating: ./data/urbansound8k/data/702.wav
#   inflating: ./data/urbansound8k/data/1296.wav
#   inflating: ./data/urbansound8k/data/6512.wav
#   inflating: ./data/urbansound8k/data/2774.wav
#   inflating: ./data/urbansound8k/data/4463.wav
#   inflating: ./data/urbansound8k/data/6274.wav
#   inflating: ./data/urbansound8k/data/8259.wav
#   inflating: ./data/urbansound8k/data/6260.wav
#   inflating: ./data/urbansound8k/data/3318.wav
#   inflating: ./data/urbansound8k/data/5769.wav
#   inflating: ./data/urbansound8k/data/2760.wav
#   inflating: ./data/urbansound8k/data/4311.wav
#   inflating: ./data/urbansound8k/data/925.wav
#   inflating: ./data/urbansound8k/data/7618.wav
#   inflating: ./data/urbansound8k/data/6506.wav
#   inflating: ./data/urbansound8k/data/1269.wav
#   inflating: ./data/urbansound8k/data/8503.wav
#   inflating: ./data/urbansound8k/data/1241.wav
#   inflating: ./data/urbansound8k/data/1527.wav
#   inflating: ./data/urbansound8k/data/6248.wav
#   inflating: ./data/urbansound8k/data/7156.wav
#   inflating: ./data/urbansound8k/data/8265.wav
#   inflating: ./data/urbansound8k/data/3330.wav
#   inflating: ./data/urbansound8k/data/5999.wav
#   inflating: ./data/urbansound8k/data/5741.wav
#   inflating: ./data/urbansound8k/data/3324.wav
#   inflating: ./data/urbansound8k/data/5755.wav
#   inflating: ./data/urbansound8k/data/7142.wav
#   inflating: ./data/urbansound8k/data/8271.wav
#   inflating: ./data/urbansound8k/data/919.wav
#   inflating: ./data/urbansound8k/data/1255.wav
#   inflating: ./data/urbansound8k/data/5033.wav
#   inflating: ./data/urbansound8k/data/2984.wav
#   inflating: ./data/urbansound8k/data/3442.wav
#   inflating: ./data/urbansound8k/data/528.wav
#   inflating: ./data/urbansound8k/data/1916.wav
#   inflating: ./data/urbansound8k/data/6089.wav
#   inflating: ./data/urbansound8k/data/272.wav
#   inflating: ./data/urbansound8k/data/4846.wav
#   inflating: ./data/urbansound8k/data/3697.wav
#   inflating: ./data/urbansound8k/data/6937.wav
#   inflating: ./data/urbansound8k/data/1080.wav
#   inflating: ./data/urbansound8k/data/6923.wav
#   inflating: ./data/urbansound8k/data/500.wav
#   inflating: ./data/urbansound8k/data/3683.wav
#   inflating: ./data/urbansound8k/data/4852.wav
#   inflating: ./data/urbansound8k/data/5594.wav
#   inflating: ./data/urbansound8k/data/7383.wav
#   inflating: ./data/urbansound8k/data/1719.wav
#   inflating: ./data/urbansound8k/data/2210.wav
#   inflating: ./data/urbansound8k/data/4661.wav
#   inflating: ./data/urbansound8k/data/3668.wav
#   inflating: ./data/urbansound8k/data/5219.wav
#   inflating: ./data/urbansound8k/data/2576.wav
#   inflating: ./data/urbansound8k/data/6710.wav
#   inflating: ./data/urbansound8k/data/8729.wav
#   inflating: ./data/urbansound8k/data/2204.wav
#   inflating: ./data/urbansound8k/data/299.wav
#   inflating: ./data/urbansound8k/data/5543.wav
#   inflating: ./data/urbansound8k/data/8067.wav
#   inflating: ./data/urbansound8k/data/7354.wav
#   inflating: ./data/urbansound8k/data/1725.wav
#   inflating: ./data/urbansound8k/data/1043.wav
#   inflating: ./data/urbansound8k/data/8701.wav
#   inflating: ./data/urbansound8k/data/7432.wav
#   inflating: ./data/urbansound8k/data/3654.wav
#   inflating: ./data/urbansound8k/data/5225.wav
#   inflating: ./data/urbansound8k/data/3640.wav
#   inflating: ./data/urbansound8k/data/3898.wav
#   inflating: ./data/urbansound8k/data/6738.wav
#   inflating: ./data/urbansound8k/data/8715.wav
#   inflating: ./data/urbansound8k/data/7426.wav
#   inflating: ./data/urbansound8k/data/8073.wav
#   inflating: ./data/urbansound8k/data/7340.wav
#   inflating: ./data/urbansound8k/data/1731.wav
#   inflating: ./data/urbansound8k/data/2238.wav
#   inflating: ./data/urbansound8k/data/5557.wav
#   inflating: ./data/urbansound8k/data/3126.wav
#   inflating: ./data/urbansound8k/data/2548.wav
#   inflating: ./data/urbansound8k/data/5227.wav
#   inflating: ./data/urbansound8k/data/4139.wav
#   inflating: ./data/urbansound8k/data/3656.wav
#   inflating: ./data/urbansound8k/data/8703.wav
#   inflating: ./data/urbansound8k/data/7430.wav
#   inflating: ./data/urbansound8k/data/1727.wav
#   inflating: ./data/urbansound8k/data/3130.wav
#   inflating: ./data/urbansound8k/data/4887.wav
#   inflating: ./data/urbansound8k/data/8071.wav
#   inflating: ./data/urbansound8k/data/8717.wav
#   inflating: ./data/urbansound8k/data/7424.wav
#   inflating: ./data/urbansound8k/data/1055.wav
#   inflating: ./data/urbansound8k/data/5233.wav
#   inflating: ./data/urbansound8k/data/3642.wav
#   inflating: ./data/urbansound8k/data/6712.wav
#   inflating: ./data/urbansound8k/data/2574.wav
#   inflating: ./data/urbansound8k/data/4663.wav
#   inflating: ./data/urbansound8k/data/2212.wav
#   inflating: ./data/urbansound8k/data/6074.wav
#   inflating: ./data/urbansound8k/data/3118.wav
#   inflating: ./data/urbansound8k/data/4677.wav
#   inflating: ./data/urbansound8k/data/2206.wav
#   inflating: ./data/urbansound8k/data/2560.wav
#   inflating: ./data/urbansound8k/data/4111.wav
#   inflating: ./data/urbansound8k/data/7418.wav
#   inflating: ./data/urbansound8k/data/1069.wav
#   inflating: ./data/urbansound8k/data/1082.wav
#   inflating: ./data/urbansound8k/data/516.wav
#   inflating: ./data/urbansound8k/data/6935.wav
#   inflating: ./data/urbansound8k/data/3695.wav
#   inflating: ./data/urbansound8k/data/5582.wav
#   inflating: ./data/urbansound8k/data/4844.wav
#   inflating: ./data/urbansound8k/data/270.wav
#   inflating: ./data/urbansound8k/data/7381.wav
#   inflating: ./data/urbansound8k/data/264.wav
#   inflating: ./data/urbansound8k/data/4688.wav
#   inflating: ./data/urbansound8k/data/3681.wav
#   inflating: ./data/urbansound8k/data/3859.wav
#   inflating: ./data/urbansound8k/data/1096.wav
#   inflating: ./data/urbansound8k/data/3871.wav
#   inflating: ./data/urbansound8k/data/6909.wav
#   inflating: ./data/urbansound8k/data/1914.wav
#   inflating: ./data/urbansound8k/data/258.wav
#   inflating: ./data/urbansound8k/data/3332.wav
#   inflating: ./data/urbansound8k/data/7154.wav
#   inflating: ./data/urbansound8k/data/1525.wav
#   inflating: ./data/urbansound8k/data/1243.wav
#   inflating: ./data/urbansound8k/data/8501.wav
#   inflating: ./data/urbansound8k/data/3454.wav
#   inflating: ./data/urbansound8k/data/2992.wav
#   inflating: ./data/urbansound8k/data/5025.wav
#   inflating: ./data/urbansound8k/data/2986.wav
#   inflating: ./data/urbansound8k/data/5031.wav
#   inflating: ./data/urbansound8k/data/1257.wav
#   inflating: ./data/urbansound8k/data/7626.wav
#   inflating: ./data/urbansound8k/data/8515.wav
#   inflating: ./data/urbansound8k/data/7140.wav
#   inflating: ./data/urbansound8k/data/1531.wav
#   inflating: ./data/urbansound8k/data/2038.wav
#   inflating: ./data/urbansound8k/data/5757.wav
#   inflating: ./data/urbansound8k/data/4449.wav
#   inflating: ./data/urbansound8k/data/2010.wav
#   inflating: ./data/urbansound8k/data/4461.wav
#   inflating: ./data/urbansound8k/data/4307.wav
#   inflating: ./data/urbansound8k/data/5019.wav
#   inflating: ./data/urbansound8k/data/2776.wav
#   inflating: ./data/urbansound8k/data/6510.wav
#   inflating: ./data/urbansound8k/data/933.wav
#   inflating: ./data/urbansound8k/data/927.wav
#   inflating: ./data/urbansound8k/data/4313.wav
#   inflating: ./data/urbansound8k/data/2004.wav
#   inflating: ./data/urbansound8k/data/4475.wav
#   inflating: ./data/urbansound8k/data/6262.wav
#   inflating: ./data/urbansound8k/data/7197.wav
#   inflating: ./data/urbansound8k/data/5780.wav
#   inflating: ./data/urbansound8k/data/2789.wav
#   inflating: ./data/urbansound8k/data/2951.wav
#   inflating: ./data/urbansound8k/data/7829.wav
#   inflating: ./data/urbansound8k/data/714.wav
#   inflating: ./data/urbansound8k/data/1294.wav
#   inflating: ./data/urbansound8k/data/3483.wav
#   inflating: ./data/urbansound8k/data/2945.wav
#   inflating: ./data/urbansound8k/data/5964.wav
#   inflating: ./data/urbansound8k/data/728.wav
#   inflating: ./data/urbansound8k/data/3246.wav
#   inflating: ./data/urbansound8k/data/4529.wav
#   inflating: ./data/urbansound8k/data/5637.wav
#   inflating: ./data/urbansound8k/data/7020.wav
#   inflating: ./data/urbansound8k/data/8313.wav
#   inflating: ./data/urbansound8k/data/8475.wav
#   inflating: ./data/urbansound8k/data/1337.wav
#   inflating: ./data/urbansound8k/data/5151.wav
#   inflating: ./data/urbansound8k/data/3520.wav
#   inflating: ./data/urbansound8k/data/3534.wav
#   inflating: ./data/urbansound8k/data/1323.wav
#   inflating: ./data/urbansound8k/data/8307.wav
#   inflating: ./data/urbansound8k/data/5623.wav
#   inflating: ./data/urbansound8k/data/4515.wav
#   inflating: ./data/urbansound8k/data/4273.wav
#   inflating: ./data/urbansound8k/data/8449.wav
#   inflating: ./data/urbansound8k/data/6464.wav
#   inflating: ./data/urbansound8k/data/853.wav
#   inflating: ./data/urbansound8k/data/2616.wav
#   inflating: ./data/urbansound8k/data/4267.wav
#   inflating: ./data/urbansound8k/data/3508.wav
#   inflating: ./data/urbansound8k/data/2170.wav
#   inflating: ./data/urbansound8k/data/1479.wav
#   inflating: ./data/urbansound8k/data/7008.wav
#   inflating: ./data/urbansound8k/data/1492.wav
#   inflating: ./data/urbansound8k/data/3285.wav
#   inflating: ./data/urbansound8k/data/2825.wav
#   inflating: ./data/urbansound8k/data/660.wav
#   inflating: ./data/urbansound8k/data/7785.wav
#   inflating: ./data/urbansound8k/data/7949.wav
#   inflating: ./data/urbansound8k/data/7791.wav
#   inflating: ./data/urbansound8k/data/2831.wav
#   inflating: ./data/urbansound8k/data/5186.wav
#   inflating: ./data/urbansound8k/data/3291.wav
#   inflating: ./data/urbansound8k/data/7961.wav
#   inflating: ./data/urbansound8k/data/884.wav
#   inflating: ./data/urbansound8k/data/2819.wav
#   inflating: ./data/urbansound8k/data/648.wav
#   inflating: ./data/urbansound8k/data/7975.wav
#   inflating: ./data/urbansound8k/data/5353.wav
#   inflating: ./data/urbansound8k/data/8677.wav
#   inflating: ./data/urbansound8k/data/6882.wav
#   inflating: ./data/urbansound8k/data/8111.wav
#   inflating: ./data/urbansound8k/data/7222.wav
#   inflating: ./data/urbansound8k/data/1653.wav
#   inflating: ./data/urbansound8k/data/5435.wav
#   inflating: ./data/urbansound8k/data/3050.wav
#   inflating: ./data/urbansound8k/data/8105.wav
#   inflating: ./data/urbansound8k/data/1647.wav
#   inflating: ./data/urbansound8k/data/8663.wav
#   inflating: ./data/urbansound8k/data/7550.wav
#   inflating: ./data/urbansound8k/data/6896.wav
#   inflating: ./data/urbansound8k/data/5347.wav
#   inflating: ./data/urbansound8k/data/2428.wav
#   inflating: ./data/urbansound8k/data/7578.wav
#   inflating: ./data/urbansound8k/data/2366.wav
#   inflating: ./data/urbansound8k/data/5409.wav
#   inflating: ./data/urbansound8k/data/3078.wav
#   inflating: ./data/urbansound8k/data/6100.wav
#   inflating: ./data/urbansound8k/data/2372.wav
#   inflating: ./data/urbansound8k/data/4703.wav
#   inflating: ./data/urbansound8k/data/2414.wav
#   inflating: ./data/urbansound8k/data/489.wav
#   inflating: ./data/urbansound8k/data/6841.wav
#   inflating: ./data/urbansound8k/data/462.wav
#   inflating: ./data/urbansound8k/data/5390.wav
#   inflating: ./data/urbansound8k/data/3939.wav
#   inflating: ./data/urbansound8k/data/3087.wav
#   inflating: ./data/urbansound8k/data/1690.wav
#   inflating: ./data/urbansound8k/data/304.wav
#   inflating: ./data/urbansound8k/data/1848.wav
#   inflating: ./data/urbansound8k/data/310.wav
#   inflating: ./data/urbansound8k/data/4924.wav
#   inflating: ./data/urbansound8k/data/5384.wav
#   inflating: ./data/urbansound8k/data/7593.wav
#   inflating: ./data/urbansound8k/data/6855.wav
#   inflating: ./data/urbansound8k/data/3905.wav
#   inflating: ./data/urbansound8k/data/338.wav
#   inflating: ./data/urbansound8k/data/1874.wav
#   inflating: ./data/urbansound8k/data/4918.wav
#   inflating: ./data/urbansound8k/data/6869.wav
#   inflating: ./data/urbansound8k/data/3911.wav
#   inflating: ./data/urbansound8k/data/4919.wav
#   inflating: ./data/urbansound8k/data/3910.wav
#   inflating: ./data/urbansound8k/data/339.wav
#   inflating: ./data/urbansound8k/data/4925.wav
#   inflating: ./data/urbansound8k/data/3092.wav
#   inflating: ./data/urbansound8k/data/311.wav
#   inflating: ./data/urbansound8k/data/477.wav
#   inflating: ./data/urbansound8k/data/7592.wav
#   inflating: ./data/urbansound8k/data/5385.wav
#   inflating: ./data/urbansound8k/data/3938.wav
#   inflating: ./data/urbansound8k/data/5391.wav
#   inflating: ./data/urbansound8k/data/6698.wav
#   inflating: ./data/urbansound8k/data/6840.wav
#   inflating: ./data/urbansound8k/data/7586.wav
#   inflating: ./data/urbansound8k/data/1849.wav
#   inflating: ./data/urbansound8k/data/305.wav
#   inflating: ./data/urbansound8k/data/2398.wav
#   inflating: ./data/urbansound8k/data/4931.wav
#   inflating: ./data/urbansound8k/data/4702.wav
#   inflating: ./data/urbansound8k/data/2373.wav
#   inflating: ./data/urbansound8k/data/6115.wav
#   inflating: ./data/urbansound8k/data/488.wav
#   inflating: ./data/urbansound8k/data/2415.wav
#   inflating: ./data/urbansound8k/data/4064.wav
#   inflating: ./data/urbansound8k/data/2401.wav
#   inflating: ./data/urbansound8k/data/4070.wav
#   inflating: ./data/urbansound8k/data/7579.wav
#   inflating: ./data/urbansound8k/data/6667.wav
#   inflating: ./data/urbansound8k/data/6101.wav
#   inflating: ./data/urbansound8k/data/4716.wav
#   inflating: ./data/urbansound8k/data/6129.wav
#   inflating: ./data/urbansound8k/data/8104.wav
#   inflating: ./data/urbansound8k/data/3051.wav
#   inflating: ./data/urbansound8k/data/4058.wav
#   inflating: ./data/urbansound8k/data/1120.wav
#   inflating: ./data/urbansound8k/data/6883.wav
#   inflating: ./data/urbansound8k/data/8676.wav
#   inflating: ./data/urbansound8k/data/1134.wav
#   inflating: ./data/urbansound8k/data/5352.wav
#   inflating: ./data/urbansound8k/data/1652.wav
#   inflating: ./data/urbansound8k/data/7223.wav
#   inflating: ./data/urbansound8k/data/8110.wav
#   inflating: ./data/urbansound8k/data/891.wav
#   inflating: ./data/urbansound8k/data/885.wav
#   inflating: ./data/urbansound8k/data/4299.wav
#   inflating: ./data/urbansound8k/data/2830.wav
#   inflating: ./data/urbansound8k/data/113.wav
#   inflating: ./data/urbansound8k/data/1493.wav
#   inflating: ./data/urbansound8k/data/7784.wav
#   inflating: ./data/urbansound8k/data/661.wav
#   inflating: ./data/urbansound8k/data/2824.wav
#   inflating: ./data/urbansound8k/data/3509.wav
#   inflating: ./data/urbansound8k/data/5178.wav
#   inflating: ./data/urbansound8k/data/12.wav
#   inflating: ./data/urbansound8k/data/7009.wav
#   inflating: ./data/urbansound8k/data/6317.wav
#   inflating: ./data/urbansound8k/data/1478.wav
#   inflating: ./data/urbansound8k/data/2171.wav
#   inflating: ./data/urbansound8k/data/4500.wav
#   inflating: ./data/urbansound8k/data/4514.wav
#   inflating: ./data/urbansound8k/data/8448.wav
#   inflating: ./data/urbansound8k/data/4272.wav
#   inflating: ./data/urbansound8k/data/2603.wav
#   inflating: ./data/urbansound8k/data/1322.wav
#   inflating: ./data/urbansound8k/data/8460.wav
#   inflating: ./data/urbansound8k/data/8306.wav
#   inflating: ./data/urbansound8k/data/7035.wav
#   inflating: ./data/urbansound8k/data/1444.wav
#   inflating: ./data/urbansound8k/data/1450.wav
#   inflating: ./data/urbansound8k/data/4528.wav
#   inflating: ./data/urbansound8k/data/6459.wav
#   inflating: ./data/urbansound8k/data/8474.wav
#   inflating: ./data/urbansound8k/data/7747.wav
#   inflating: ./data/urbansound8k/data/7800.wav
#   inflating: ./data/urbansound8k/data/8299.wav
#   inflating: ./data/urbansound8k/data/7814.wav
#   inflating: ./data/urbansound8k/data/729.wav
#   inflating: ./data/urbansound8k/data/2944.wav
#   inflating: ./data/urbansound8k/data/3482.wav
#   inflating: ./data/urbansound8k/data/1295.wav
#   inflating: ./data/urbansound8k/data/7196.wav
#   inflating: ./data/urbansound8k/data/6288.wav
#   inflating: ./data/urbansound8k/data/7828.wav
#   inflating: ./data/urbansound8k/data/2950.wav
#   inflating: ./data/urbansound8k/data/3496.wav
#   inflating: ./data/urbansound8k/data/2788.wav
#   inflating: ./data/urbansound8k/data/2763.wav
#   inflating: ./data/urbansound8k/data/926.wav
#   inflating: ./data/urbansound8k/data/6505.wav
#   inflating: ./data/urbansound8k/data/6263.wav
#   inflating: ./data/urbansound8k/data/4474.wav
#   inflating: ./data/urbansound8k/data/1518.wav
#   inflating: ./data/urbansound8k/data/7169.wav
#   inflating: ./data/urbansound8k/data/932.wav
#   inflating: ./data/urbansound8k/data/6511.wav
#   inflating: ./data/urbansound8k/data/3469.wav
#   inflating: ./data/urbansound8k/data/8514.wav
#   inflating: ./data/urbansound8k/data/1256.wav
#   inflating: ./data/urbansound8k/data/2987.wav
#   inflating: ./data/urbansound8k/data/3441.wav
#   inflating: ./data/urbansound8k/data/1530.wav
#   inflating: ./data/urbansound8k/data/8272.wav
#   inflating: ./data/urbansound8k/data/7141.wav
#   inflating: ./data/urbansound8k/data/8266.wav
#   inflating: ./data/urbansound8k/data/7155.wav
#   inflating: ./data/urbansound8k/data/3333.wav
#   inflating: ./data/urbansound8k/data/5742.wav
#   inflating: ./data/urbansound8k/data/2993.wav
#   inflating: ./data/urbansound8k/data/3455.wav
#   inflating: ./data/urbansound8k/data/8500.wav
#   inflating: ./data/urbansound8k/data/7633.wav
#   inflating: ./data/urbansound8k/data/1242.wav
#   inflating: ./data/urbansound8k/data/3864.wav
#   inflating: ./data/urbansound8k/data/6908.wav
#   inflating: ./data/urbansound8k/data/3870.wav
#   inflating: ./data/urbansound8k/data/4879.wav
#   inflating: ./data/urbansound8k/data/1901.wav
#   inflating: ./data/urbansound8k/data/4851.wav
#   inflating: ./data/urbansound8k/data/5597.wav
#   inflating: ./data/urbansound8k/data/7380.wav
#   inflating: ./data/urbansound8k/data/1929.wav
#   inflating: ./data/urbansound8k/data/6920.wav
#   inflating: ./data/urbansound8k/data/3680.wav
#   inflating: ./data/urbansound8k/data/6934.wav
#   inflating: ./data/urbansound8k/data/1083.wav
#   inflating: ./data/urbansound8k/data/271.wav
#   inflating: ./data/urbansound8k/data/5583.wav
#   inflating: ./data/urbansound8k/data/4676.wav
#   inflating: ./data/urbansound8k/data/6061.wav
#   inflating: ./data/urbansound8k/data/1068.wav
#   inflating: ./data/urbansound8k/data/7419.wav
#   inflating: ./data/urbansound8k/data/4110.wav
#   inflating: ./data/urbansound8k/data/4104.wav
#   inflating: ./data/urbansound8k/data/2575.wav
#   inflating: ./data/urbansound8k/data/8058.wav
#   inflating: ./data/urbansound8k/data/4662.wav
#   inflating: ./data/urbansound8k/data/7343.wav
#   inflating: ./data/urbansound8k/data/5554.wav
#   inflating: ./data/urbansound8k/data/3125.wav
#   inflating: ./data/urbansound8k/data/1054.wav
#   inflating: ./data/urbansound8k/data/7425.wav
#   inflating: ./data/urbansound8k/data/8716.wav
#   inflating: ./data/urbansound8k/data/1040.wav
#   inflating: ./data/urbansound8k/data/7431.wav
#   inflating: ./data/urbansound8k/data/3657.wav
#   inflating: ./data/urbansound8k/data/4138.wav
#   inflating: ./data/urbansound8k/data/5226.wav
#   inflating: ./data/urbansound8k/data/2549.wav
#   inflating: ./data/urbansound8k/data/4886.wav
#   inflating: ./data/urbansound8k/data/5540.wav
#   inflating: ./data/urbansound8k/data/3131.wav
#   inflating: ./data/urbansound8k/data/8064.wav
#   inflating: ./data/urbansound8k/data/6049.wav
#   inflating: ./data/urbansound8k/data/2512.wav
#   inflating: ./data/urbansound8k/data/4163.wav
#   inflating: ./data/urbansound8k/data/6774.wav
#   inflating: ./data/urbansound8k/data/6012.wav
#   inflating: ./data/urbansound8k/data/4611.wav
#   inflating: ./data/urbansound8k/data/2260.wav
#   inflating: ./data/urbansound8k/data/1769.wav
#   inflating: ./data/urbansound8k/data/6760.wav
#   inflating: ./data/urbansound8k/data/2506.wav
#   inflating: ./data/urbansound8k/data/7456.wav
#   inflating: ./data/urbansound8k/data/6990.wav
#   inflating: ./data/urbansound8k/data/1027.wav
#   inflating: ./data/urbansound8k/data/6748.wav
#   inflating: ./data/urbansound8k/data/5241.wav
#   inflating: ./data/urbansound8k/data/3630.wav
#   inflating: ./data/urbansound8k/data/3156.wav
#   inflating: ./data/urbansound8k/data/1741.wav
#   inflating: ./data/urbansound8k/data/7330.wav
#   inflating: ./data/urbansound8k/data/1999.wav
#   inflating: ./data/urbansound8k/data/1755.wav
#   inflating: ./data/urbansound8k/data/5533.wav
#   inflating: ./data/urbansound8k/data/5255.wav
#   inflating: ./data/urbansound8k/data/3624.wav
#   inflating: ./data/urbansound8k/data/6984.wav
#   inflating: ./data/urbansound8k/data/1966.wav
#   inflating: ./data/urbansound8k/data/3803.wav
#   inflating: ./data/urbansound8k/data/570.wav
#   inflating: ./data/urbansound8k/data/7495.wav
#   inflating: ./data/urbansound8k/data/1782.wav
#   inflating: ./data/urbansound8k/data/216.wav
#   inflating: ./data/urbansound8k/data/4822.wav
#   inflating: ./data/urbansound8k/data/3195.wav
#   inflating: ./data/urbansound8k/data/4836.wav
#   inflating: ./data/urbansound8k/data/202.wav
#   inflating: ./data/urbansound8k/data/1796.wav
#   inflating: ./data/urbansound8k/data/564.wav
#   inflating: ./data/urbansound8k/data/6947.wav
#   inflating: ./data/urbansound8k/data/5719.wav
#   inflating: ./data/urbansound8k/data/6210.wav
#   inflating: ./data/urbansound8k/data/1219.wav
#   inflating: ./data/urbansound8k/data/955.wav
#   inflating: ./data/urbansound8k/data/4361.wav
#   inflating: ./data/urbansound8k/data/2710.wav
#   inflating: ./data/urbansound8k/data/4375.wav
#   inflating: ./data/urbansound8k/data/6562.wav
#   inflating: ./data/urbansound8k/data/799.wav
#   inflating: ./data/urbansound8k/data/941.wav
#   inflating: ./data/urbansound8k/data/8229.wav
#   inflating: ./data/urbansound8k/data/6204.wav
#   inflating: ./data/urbansound8k/data/4413.wav
#   inflating: ./data/urbansound8k/data/8201.wav
#   inflating: ./data/urbansound8k/data/5725.wav
#   inflating: ./data/urbansound8k/data/3354.wav
#   inflating: ./data/urbansound8k/data/3432.wav
#   inflating: ./data/urbansound8k/data/5043.wav
#   inflating: ./data/urbansound8k/data/1231.wav
#   inflating: ./data/urbansound8k/data/7898.wav
#   inflating: ./data/urbansound8k/data/4349.wav
#   inflating: ./data/urbansound8k/data/2738.wav
#   inflating: ./data/urbansound8k/data/5057.wav
#   inflating: ./data/urbansound8k/data/5731.wav
#   inflating: ./data/urbansound8k/data/8215.wav
#   inflating: ./data/urbansound8k/data/7126.wav
#   inflating: ./data/urbansound8k/data/5902.wav
#   inflating: ./data/urbansound8k/data/8598.wav
#   inflating: ./data/urbansound8k/data/996.wav
#   inflating: ./data/urbansound8k/data/7873.wav
#   inflating: ./data/urbansound8k/data/7867.wav
#   inflating: ./data/urbansound8k/data/3397.wav
#   inflating: ./data/urbansound8k/data/2089.wav
#   inflating: ./data/urbansound8k/data/7697.wav
#   inflating: ./data/urbansound8k/data/6589.wav
#   inflating: ./data/urbansound8k/data/772.wav
#   inflating: ./data/urbansound8k/data/5094.wav
#   inflating: ./data/urbansound8k/data/7683.wav
#   inflating: ./data/urbansound8k/data/766.wav
#   inflating: ./data/urbansound8k/data/3383.wav
#   inflating: ./data/urbansound8k/data/4573.wav
#   inflating: ./data/urbansound8k/data/2102.wav
#   inflating: ./data/urbansound8k/data/6364.wav
#   inflating: ./data/urbansound8k/data/821.wav
#   inflating: ./data/urbansound8k/data/6402.wav
#   inflating: ./data/urbansound8k/data/61.wav
#   inflating: ./data/urbansound8k/data/2664.wav
#   inflating: ./data/urbansound8k/data/4201.wav
#   inflating: ./data/urbansound8k/data/835.wav
#   inflating: ./data/urbansound8k/data/6416.wav
#   inflating: ./data/urbansound8k/data/6370.wav
#   inflating: ./data/urbansound8k/data/2116.wav
#   inflating: ./data/urbansound8k/data/6358.wav
# ...
#   inflating: ./data/urbansound8k/data/2596.wav
#   inflating: ./data/urbansound8k/data/3850.wav
#   inflating: ./data/urbansound8k/data/7388.wav
#   inflating: ./data/urbansound8k/data/1921.wav
#   inflating: ./data/urbansound8k/data/6096.wav
#   inflating: ./data/urbansound8k/data/1935.wav
#   inflating: ./data/urbansound8k/data/6082.wav
#   inflating: ./data/urbansound8k/data/4695.wav
#   inflating: ./data/urbansound8k/data/2582.wav
#   inflating: ./data/urbansound8k/data/3844.wav
#   inflating: ./data/urbansound8k/data/7175.wav
#   inflating: ./data/urbansound8k/data/8246.wav
#   inflating: ./data/urbansound8k/data/5762.wav
#   inflating: ./data/urbansound8k/data/3475.wav
#   inflating: ./data/urbansound8k/data/5004.wav
#   inflating: ./data/urbansound8k/data/1262.wav
#   inflating: ./data/urbansound8k/data/7613.wav
#   inflating: ./data/urbansound8k/data/8520.wav
#   inflating: ./data/urbansound8k/data/1276.wav
#   inflating: ./data/urbansound8k/data/7607.wav
#   inflating: ./data/urbansound8k/data/8534.wav
#   inflating: ./data/urbansound8k/data/3461.wav
#   inflating: ./data/urbansound8k/data/5010.wav
#   inflating: ./data/urbansound8k/data/2019.wav
#   inflating: ./data/urbansound8k/data/3307.wav
#   inflating: ./data/urbansound8k/data/7161.wav
#   inflating: ./data/urbansound8k/data/8252.wav
#   inflating: ./data/urbansound8k/data/1510.wav
#   inflating: ./data/urbansound8k/data/2031.wav
#   inflating: ./data/urbansound8k/data/4440.wav
#   inflating: ./data/urbansound8k/data/7149.wav
#   inflating: ./data/urbansound8k/data/6531.wav
#   inflating: ./data/urbansound8k/data/912.wav
#   inflating: ./data/urbansound8k/data/3449.wav
#   inflating: ./data/urbansound8k/data/4326.wav
#   inflating: ./data/urbansound8k/data/5038.wav
#   inflating: ./data/urbansound8k/data/2757.wav
#   inflating: ./data/urbansound8k/data/906.wav
#   inflating: ./data/urbansound8k/data/8508.wav
#   inflating: ./data/urbansound8k/data/6243.wav
#   inflating: ./data/urbansound8k/data/2025.wav
#   inflating: ./data/urbansound8k/data/4454.wav
#   inflating: ./data/urbansound8k/data/5992.wav
#   inflating: ./data/urbansound8k/data/8285.wav
#   inflating: ./data/urbansound8k/data/735.wav
#   inflating: ./data/urbansound8k/data/721.wav
#   inflating: ./data/urbansound8k/data/6294.wav
#   inflating: ./data/urbansound8k/data/4483.wav
#   inflating: ./data/urbansound8k/data/2794.wav
#   inflating: ./data/urbansound8k/data/709.wav
#   inflating: ./data/urbansound8k/data/1289.wav
#   inflating: ./data/urbansound8k/data/2780.wav
#   inflating: ./data/urbansound8k/data/5951.wav
#   inflating: ./data/urbansound8k/data/1470.wav
#   inflating: ./data/urbansound8k/data/7001.wav
#   inflating: ./data/urbansound8k/data/8332.wav
#   inflating: ./data/urbansound8k/data/3267.wav
#   inflating: ./data/urbansound8k/data/5616.wav
#   inflating: ./data/urbansound8k/data/2179.wav
#   inflating: ./data/urbansound8k/data/3501.wav
#   inflating: ./data/urbansound8k/data/1316.wav
#   inflating: ./data/urbansound8k/data/8440.wav
#   inflating: ./data/urbansound8k/data/1302.wav
#   inflating: ./data/urbansound8k/data/3515.wav
#   inflating: ./data/urbansound8k/data/3273.wav
#   inflating: ./data/urbansound8k/data/7015.wav
#   inflating: ./data/urbansound8k/data/4534.wav
#   inflating: ./data/urbansound8k/data/2145.wav
#   inflating: ./data/urbansound8k/data/6323.wav
#   inflating: ./data/urbansound8k/data/26.wav
#   inflating: ./data/urbansound8k/data/6445.wav
#   inflating: ./data/urbansound8k/data/2623.wav
#   inflating: ./data/urbansound8k/data/4252.wav
#   inflating: ./data/urbansound8k/data/2637.wav
#   inflating: ./data/urbansound8k/data/5158.wav
#   inflating: ./data/urbansound8k/data/4246.wav
#   inflating: ./data/urbansound8k/data/3529.wav
#   inflating: ./data/urbansound8k/data/872.wav
#   inflating: ./data/urbansound8k/data/6451.wav
#   inflating: ./data/urbansound8k/data/32.wav
#   inflating: ./data/urbansound8k/data/7997.wav
#   inflating: ./data/urbansound8k/data/1458.wav
#   inflating: ./data/urbansound8k/data/6337.wav
#   inflating: ./data/urbansound8k/data/7029.wav
#   inflating: ./data/urbansound8k/data/899.wav
#   inflating: ./data/urbansound8k/data/655.wav
#   inflating: ./data/urbansound8k/data/8483.wav
#   inflating: ./data/urbansound8k/data/2186.wav
#   inflating: ./data/urbansound8k/data/3298.wav
#   inflating: ./data/urbansound8k/data/4291.wav
#   inflating: ./data/urbansound8k/data/6486.wav
#   inflating: ./data/urbansound8k/data/669.wav
#   inflating: ./data/urbansound8k/data/7954.wav
#   inflating: ./data/urbansound8k/data/4285.wav
#   inflating: ./data/urbansound8k/data/2192.wav
#   inflating: ./data/urbansound8k/data/5825.wav
#   inflating: ./data/urbansound8k/data/480.wav
#   inflating: ./data/urbansound8k/data/8656.wav
#   inflating: ./data/urbansound8k/data/7565.wav
#   inflating: ./data/urbansound8k/data/3703.wav
#   inflating: ./data/urbansound8k/data/5414.wav
#   inflating: ./data/urbansound8k/data/8130.wav
#   inflating: ./data/urbansound8k/data/7203.wav
#   inflating: ./data/urbansound8k/data/1672.wav
#   inflating: ./data/urbansound8k/data/7217.wav
#   inflating: ./data/urbansound8k/data/6109.wav
#   inflating: ./data/urbansound8k/data/1666.wav
#   inflating: ./data/urbansound8k/data/5400.wav
#   inflating: ./data/urbansound8k/data/3071.wav
#   inflating: ./data/urbansound8k/data/3717.wav
#   inflating: ./data/urbansound8k/data/4078.wav
#   inflating: ./data/urbansound8k/data/1100.wav
#   inflating: ./data/urbansound8k/data/4050.wav
#   inflating: ./data/urbansound8k/data/2421.wav
#   inflating: ./data/urbansound8k/data/6647.wav
#   inflating: ./data/urbansound8k/data/1896.wav
#   inflating: ./data/urbansound8k/data/6121.wav
#   inflating: ./data/urbansound8k/data/2347.wav
#   inflating: ./data/urbansound8k/data/4736.wav
#   inflating: ./data/urbansound8k/data/2353.wav
#   inflating: ./data/urbansound8k/data/4722.wav
#   inflating: ./data/urbansound8k/data/8118.wav
#   inflating: ./data/urbansound8k/data/6653.wav
#   inflating: ./data/urbansound8k/data/4044.wav
#   inflating: ./data/urbansound8k/data/3918.wav
#   inflating: ./data/urbansound8k/data/8695.wav
#   inflating: ./data/urbansound8k/data/6860.wav
#   inflating: ./data/urbansound8k/data/1869.wav
#   inflating: ./data/urbansound8k/data/4911.wav
#   inflating: ./data/urbansound8k/data/4905.wav
#   inflating: ./data/urbansound8k/data/331.wav
#   inflating: ./data/urbansound8k/data/8681.wav
#   inflating: ./data/urbansound8k/data/457.wav
#   inflating: ./data/urbansound8k/data/3924.wav
#   inflating: ./data/urbansound8k/data/4093.wav
#   inflating: ./data/urbansound8k/data/2384.wav
#   inflating: ./data/urbansound8k/data/319.wav
#   inflating: ./data/urbansound8k/data/1699.wav
#   inflating: ./data/urbansound8k/data/1841.wav
#   inflating: ./data/urbansound8k/data/2390.wav
#   inflating: ./data/urbansound8k/data/3930.wav
#   inflating: ./data/urbansound8k/data/4087.wav
#   inflating: ./data/urbansound8k/data/4938.wav
#   inflating: ./data/urbansound8k/data/1840.wav
#   inflating: ./data/urbansound8k/data/6691.wav
#   inflating: ./data/urbansound8k/data/4086.wav
#   inflating: ./data/urbansound8k/data/5398.wav
#   inflating: ./data/urbansound8k/data/3925.wav
#   inflating: ./data/urbansound8k/data/1854.wav
#   inflating: ./data/urbansound8k/data/318.wav
#   inflating: ./data/urbansound8k/data/330.wav
#   inflating: ./data/urbansound8k/data/4904.wav
#   inflating: ./data/urbansound8k/data/456.wav
#   inflating: ./data/urbansound8k/data/6875.wav
#   inflating: ./data/urbansound8k/data/442.wav
#   inflating: ./data/urbansound8k/data/8694.wav
#   inflating: ./data/urbansound8k/data/3919.wav
#   inflating: ./data/urbansound8k/data/1868.wav
#   inflating: ./data/urbansound8k/data/324.wav
#   inflating: ./data/urbansound8k/data/6134.wav
#   inflating: ./data/urbansound8k/data/1883.wav
#   inflating: ./data/urbansound8k/data/8119.wav
#   inflating: ./data/urbansound8k/data/4723.wav
#   inflating: ./data/urbansound8k/data/4045.wav
#   inflating: ./data/urbansound8k/data/6652.wav
#   inflating: ./data/urbansound8k/data/7558.wav
#   inflating: ./data/urbansound8k/data/1129.wav
#   inflating: ./data/urbansound8k/data/2420.wav
#   inflating: ./data/urbansound8k/data/4737.wav
#   inflating: ./data/urbansound8k/data/5429.wav
#   inflating: ./data/urbansound8k/data/6120.wav
#   inflating: ./data/urbansound8k/data/1897.wav
#   inflating: ./data/urbansound8k/data/3070.wav
#   inflating: ./data/urbansound8k/data/1667.wav
#   inflating: ./data/urbansound8k/data/6108.wav
#   inflating: ./data/urbansound8k/data/7216.wav
#   inflating: ./data/urbansound8k/data/8125.wav
#   inflating: ./data/urbansound8k/data/7570.wav
#   inflating: ./data/urbansound8k/data/8643.wav
#   inflating: ./data/urbansound8k/data/495.wav
#   inflating: ./data/urbansound8k/data/2408.wav
#   inflating: ./data/urbansound8k/data/5373.wav
#   inflating: ./data/urbansound8k/data/3702.wav
#   inflating: ./data/urbansound8k/data/8657.wav
#   inflating: ./data/urbansound8k/data/1115.wav
#   inflating: ./data/urbansound8k/data/1673.wav
#   inflating: ./data/urbansound8k/data/7202.wav
#   inflating: ./data/urbansound8k/data/8131.wav
#   inflating: ./data/urbansound8k/data/5415.wav
#   inflating: ./data/urbansound8k/data/7955.wav
#   inflating: ./data/urbansound8k/data/6493.wav
#   inflating: ./data/urbansound8k/data/5824.wav
#   inflating: ./data/urbansound8k/data/2193.wav
#   inflating: ./data/urbansound8k/data/3299.wav
#   inflating: ./data/urbansound8k/data/7941.wav
#   inflating: ./data/urbansound8k/data/6487.wav
#   inflating: ./data/urbansound8k/data/4290.wav
#   inflating: ./data/urbansound8k/data/8482.wav
#   inflating: ./data/urbansound8k/data/654.wav
#   inflating: ./data/urbansound8k/data/7969.wav
#   inflating: ./data/urbansound8k/data/2811.wav
#   inflating: ./data/urbansound8k/data/5818.wav
#   inflating: ./data/urbansound8k/data/132.wav
#   inflating: ./data/urbansound8k/data/2805.wav
#   inflating: ./data/urbansound8k/data/8496.wav
#   inflating: ./data/urbansound8k/data/898.wav
#   inflating: ./data/urbansound8k/data/7996.wav
#   inflating: ./data/urbansound8k/data/6450.wav
#   inflating: ./data/urbansound8k/data/33.wav
#   inflating: ./data/urbansound8k/data/3528.wav
#   inflating: ./data/urbansound8k/data/4247.wav
#   inflating: ./data/urbansound8k/data/5159.wav
#   inflating: ./data/urbansound8k/data/2636.wav
#   inflating: ./data/urbansound8k/data/2150.wav
#   inflating: ./data/urbansound8k/data/4521.wav
#   inflating: ./data/urbansound8k/data/7028.wav
#   inflating: ./data/urbansound8k/data/6336.wav
#   inflating: ./data/urbansound8k/data/1459.wav
#   inflating: ./data/urbansound8k/data/6322.wav
#   inflating: ./data/urbansound8k/data/2144.wav
#   inflating: ./data/urbansound8k/data/4535.wav
#   inflating: ./data/urbansound8k/data/4253.wav
#   inflating: ./data/urbansound8k/data/7982.wav
#   inflating: ./data/urbansound8k/data/27.wav
#   inflating: ./data/urbansound8k/data/867.wav
#   inflating: ./data/urbansound8k/data/8469.wav
#   inflating: ./data/urbansound8k/data/3514.wav
#   inflating: ./data/urbansound8k/data/5165.wav
#   inflating: ./data/urbansound8k/data/1303.wav
#   inflating: ./data/urbansound8k/data/697.wav
#   inflating: ./data/urbansound8k/data/8441.wav
#   inflating: ./data/urbansound8k/data/8327.wav
#   inflating: ./data/urbansound8k/data/7014.wav
#   inflating: ./data/urbansound8k/data/3272.wav
#   inflating: ./data/urbansound8k/data/4509.wav
#   inflating: ./data/urbansound8k/data/3266.wav
#   inflating: ./data/urbansound8k/data/8333.wav
#   inflating: ./data/urbansound8k/data/7000.wav
#   inflating: ./data/urbansound8k/data/1471.wav
#   inflating: ./data/urbansound8k/data/683.wav
#   inflating: ./data/urbansound8k/data/1317.wav
#   inflating: ./data/urbansound8k/data/6478.wav
#   inflating: ./data/urbansound8k/data/7766.wav
#   inflating: ./data/urbansound8k/data/5171.wav
#   inflating: ./data/urbansound8k/data/2959.wav
#   inflating: ./data/urbansound8k/data/2781.wav
#   inflating: ./data/urbansound8k/data/7821.wav
#   inflating: ./data/urbansound8k/data/5788.wav
#   inflating: ./data/urbansound8k/data/5950.wav
#   inflating: ./data/urbansound8k/data/5944.wav
#   inflating: ./data/urbansound8k/data/4482.wav
#   inflating: ./data/urbansound8k/data/6295.wav
#   inflating: ./data/urbansound8k/data/7835.wav
#   inflating: ./data/urbansound8k/data/2795.wav
#   inflating: ./data/urbansound8k/data/720.wav
#   inflating: ./data/urbansound8k/data/2971.wav
#   inflating: ./data/urbansound8k/data/734.wav
#   inflating: ./data/urbansound8k/data/907.wav
#   inflating: ./data/urbansound8k/data/6524.wav
#   inflating: ./data/urbansound8k/data/4333.wav
#   inflating: ./data/urbansound8k/data/6256.wav
#   inflating: ./data/urbansound8k/data/7148.wav
#   inflating: ./data/urbansound8k/data/2756.wav
#   inflating: ./data/urbansound8k/data/4327.wav
#   inflating: ./data/urbansound8k/data/913.wav
#   inflating: ./data/urbansound8k/data/6530.wav
#   inflating: ./data/urbansound8k/data/5011.wav
#   inflating: ./data/urbansound8k/data/8535.wav
#   inflating: ./data/urbansound8k/data/6518.wav
#   inflating: ./data/urbansound8k/data/1277.wav
#   inflating: ./data/urbansound8k/data/1511.wav
#   inflating: ./data/urbansound8k/data/8253.wav
#   inflating: ./data/urbansound8k/data/3306.wav
#   inflating: ./data/urbansound8k/data/2018.wav
#   inflating: ./data/urbansound8k/data/5763.wav
#   inflating: ./data/urbansound8k/data/8247.wav
#   inflating: ./data/urbansound8k/data/7174.wav
#   inflating: ./data/urbansound8k/data/7612.wav
#   inflating: ./data/urbansound8k/data/5005.wav
#   inflating: ./data/urbansound8k/data/3474.wav
#   inflating: ./data/urbansound8k/data/6083.wav
#   inflating: ./data/urbansound8k/data/278.wav
#   inflating: ./data/urbansound8k/data/3851.wav
#   inflating: ./data/urbansound8k/data/2597.wav
#   inflating: ./data/urbansound8k/data/3689.wav
#   inflating: ./data/urbansound8k/data/6929.wav
#   inflating: ./data/urbansound8k/data/7389.wav
#   inflating: ./data/urbansound8k/data/4680.wav
#   inflating: ./data/urbansound8k/data/4858.wav
#   inflating: ./data/urbansound8k/data/1908.wav
#   inflating: ./data/urbansound8k/data/8092.wav
#   inflating: ./data/urbansound8k/data/4870.wav
#   inflating: ./data/urbansound8k/data/3879.wav
#   inflating: ./data/urbansound8k/data/6901.wav
#   inflating: ./data/urbansound8k/data/522.wav
#   inflating: ./data/urbansound8k/data/6915.wav
#   inflating: ./data/urbansound8k/data/4864.wav
#   inflating: ./data/urbansound8k/data/250.wav
#   inflating: ./data/urbansound8k/data/8086.wav
#   inflating: ./data/urbansound8k/data/6040.wav
#   inflating: ./data/urbansound8k/data/2226.wav
#   inflating: ./data/urbansound8k/data/4657.wav
#   inflating: ./data/urbansound8k/data/3138.wav
#   inflating: ./data/urbansound8k/data/4131.wav
#   inflating: ./data/urbansound8k/data/3886.wav
#   inflating: ./data/urbansound8k/data/1049.wav
#   inflating: ./data/urbansound8k/data/6726.wav
#   inflating: ./data/urbansound8k/data/6732.wav
#   inflating: ./data/urbansound8k/data/4125.wav
#   inflating: ./data/urbansound8k/data/4643.wav
#   inflating: ./data/urbansound8k/data/8079.wav
#   inflating: ./data/urbansound8k/data/6054.wav
#   inflating: ./data/urbansound8k/data/3104.wav
#   inflating: ./data/urbansound8k/data/7362.wav
#   inflating: ./data/urbansound8k/data/1713.wav
#   inflating: ./data/urbansound8k/data/7404.wav
#   inflating: ./data/urbansound8k/data/3662.wav
#   inflating: ./data/urbansound8k/data/3676.wav
#   inflating: ./data/urbansound8k/data/4119.wav
#   inflating: ./data/urbansound8k/data/2568.wav
#   inflating: ./data/urbansound8k/data/1061.wav
#   inflating: ./data/urbansound8k/data/7410.wav
#   inflating: ./data/urbansound8k/data/8723.wav
#   inflating: ./data/urbansound8k/data/7376.wav
#   inflating: ./data/urbansound8k/data/6068.wav
#   inflating: ./data/urbansound8k/data/5561.wav
#   inflating: ./data/urbansound8k/data/3110.wav

# %%
# %matplotlib inline

from IPython import display
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset

import torchaudio

assert torch.__version__.startswith('1.8.0')
assert torchaudio.__version__ == '0.8.0'

device='cuda:0'

# %% [markdown]
# # Классификация аудиозаписей.

# %% [markdown]
# В этом домашнем задании Вам предстоит классифицировать аудиозаписи из датасета [UrbanSound8K](https://urbansounddataset.weebly.com/urbansound8k.html).
#
# Данный датасет состоит из 8732 записей, разбитых на train/val/test датасеты.
#
# ![image](https://paperswithcode.com/media/datasets/UrbanSound8K-0000003722-02faef06.jpg)
#
# Каждая аудиозапись содержит запись шума города и принадлежит одному из 10 классов:
#
# `[air_conditioner, car_horn, children_playing, dog_bark, drilling, engine_idling, gun_shot, jackhammer, siren, street_music]`

# %% [markdown]
# ## Задание 1 (1 балл). Знакомство с данными.
#
# 1. Скачайте датасет из [Google Drive](https://drive.google.com/file/d/12emmtpodmo1783e6VOOEjV20zAKl5dZR/view?usp=sharing) c и распакуйте в папку `./data`.
#
# 2. Напишите `AudioDataset` класс, который будет принимать путь к файлам `train_part.csv` и `val_part.csv` и возращать тройки объектов `(x, y, len)`, где `x` - аудиозапись, `y` - класс аудиозаписи, `len` - длина аудиозаписи. Аудиозаписи **не должны постоянно храниться в RAM**, подгрузку _wav_ файлов надо сделать при запросе через `__getitem__` метод. Кроме того, надо сделать паддинг аудиозаписи - если она короче чем `pad_size` параметр, надо дополнять ее нулями.
#
# 3. С помощью функции `display.Audio` проиграйте в ноутбуке пару аудиозаписей.

# %%
# скачаем и распакуем данные
"""
# !rm -r ./data
# !mkdir ./data/
# !pip install gdown
# !cd ./data && gdown https://drive.google.com/uc?id=12emmtpodmo1783e6VOOEjV20zAKl5dZR && unzip HW2_dataset.zip && rm HW2_dataset.zip
"""
# Out:
# '\n!rm -r ./data\n!mkdir ./data/\n!pip install gdown\n!cd ./data && gdown https://drive.google.com/uc?id=12emmtpodmo1783e6VOOEjV20zAKl5dZR && unzip HW2_dataset.zip && rm HW2_dataset.zip\n'

# %%
# классы данных
classes = ['air_conditioner', 'car_horn', 'children_playing', 'dog_bark',
           'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 
           'siren', 'street_music']

# %%
import os

import pandas as pd
import numpy as np


class AudioDataset(Dataset):
    def __init__(self, path_to_csv: str, 
                 path_to_folder: str, 
                 pad_size: int=384000,
                 sr: int = 44100):
        self.csv: pd.DataFrame = pd.read_csv(path_to_csv)[['ID', 'Class']]
        self.path_to_folder = path_to_folder
        self.pad_size = pad_size

        self.sr = sr

        self.class_to_idx = {classes[i]: i for i in range(10)}

    def __getitem__(self, index: int):
        ### YOUR CODE IS HERE ######
        
        output = self.csv.iloc[index]
        
        if len(output) == 2:
            id, classs = output
            y = torch.tensor(self.class_to_idx[classs])
        else:
            id, = output
            y = torch.LongTensor([-1])
       
        path = os.path.join(self.path_to_folder, f'{id}.wav')
        wav, sr = torchaudio.load(path)
        if sr != self.sr:
            resampler = torchaudio.transforms.Resample(sr, self.sr)
            wav = resampler(wav)
        wav = wav.squeeze()
        wav_pad = torch.cat([wav, wav.new_zeros(self.pad_size - wav.size(0))], 0)
        instance = {
            'x': torch.reshape(wav_pad, (-1,)),
            'y': y,
            'len': len(wav)
        }
        
        return instance

        ### THE END OF YOUR CODE ###

    def __len__(self):
        return self.csv.shape[0]

# %%
# создадим датасеты
train_dataset = AudioDataset('./data/urbansound8k/train_part.csv', './data/urbansound8k/data')
val_dataset = AudioDataset('./data/urbansound8k/val_part.csv', './data/urbansound8k/data')

# %%
# проверим размеры датасетов
assert len(train_dataset) == 4500
assert len(val_dataset) == 935

# %%
# проверим возращаемые значения __getitem__
item = train_dataset.__getitem__(0)

assert item['x'].shape == (384000, )
assert item['y'] == 0
assert item['len'] == 176400

# %%
# нарисуем и проиграем аудиозаписить
item = train_dataset.__getitem__(0)
plt.figure(figsize=(16, 8))
plt.plot(item['x'])

display.Audio(item['x'], rate=train_dataset.sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# создадим даталоадеры
train_dataloader = DataLoader(train_dataset, 32, shuffle=True,
                              pin_memory=True, drop_last=True)
val_dataloader = DataLoader(val_dataset, 32,
                            pin_memory=True)

# %% [markdown]
# ## Задание 2. Рекуррентная сеть для классификации аудиозаписей по сырому сигналу (2 балла)
#
# По своей сути аудиозапись является ни чем иным, как временным рядом - замеры микрофона делаются через равные промежутки времени и хранятся в виде последовательности.
#
# Как известно, рекуррентные сети отлично подходят для работы с различными последовательностями, в том числе и с временными рядами.
#
# Обучим простую реккурентную сеть для классификации аудиозаписей.
#
# 1. Разбейте аудизаписить на окошки размером `1024` с шагом `256`. Для этих целей отлично подойдет метод `torch.Tensor.unfold`.
# 1. Применим к каждому получившемуся окну аудиосигнала полносвязную сеть с активациями `ReLU` и  внутренними размерностям `(1024 -> 256 -> 64 -> 16)`.
# 2. По получившимся последовательностям пройдемся двунаправленой (`bidirectional=True`) LSTM с двумя слоями (`layers=2`).
# 3. Склеим c помощью `torch.cat` последние `hidden_state` для каждого слоя и применим к ним полносвязную сеть `(2 * hidden_size * num_layers -> 256 -> 10)` с активацией `ReLU`.
#
# ![title](https://github.com/hse-ds/iad-applied-ds/blob/master/2021/hw/hw2/imgs/rnn_raw.png?raw=1)
#
# *Совет*: для убыстрения обучения имеет смысл в полносвязные сети добавить `BatchNorm`.

# %%
from torchaudio.transforms import MelSpectrogram

class RecurrentRawAudioClassifier(nn.Module):
  def __init__(self, 
               num_classes=10,
               window_length=1024,
               hop_length=256,
               hidden=256,
               num_layers=2):
    super().__init__()

    self.window_length = window_length
    self.hop_length = hop_length

    ### YOUR CODE IS HERE ######
    self.first_mlp = nn.Sequential(
        nn.Linear(self.window_length, 256),
        nn.BatchNorm1d(1497), 
        nn.ReLU(),
        nn.Linear(256, 64),
        nn.BatchNorm1d(1497), 
        nn.ReLU(),
        nn.Linear(64, 16)
    )
    self.rnn = nn.LSTM(16, hidden, num_layers, bidirectional=True, batch_first=True)

    self.final_mlp = nn.Sequential(
        nn.Linear(2 * hidden * num_layers, 256),
        nn.BatchNorm1d(256),
        nn.ReLU(),
        nn.Linear(256, 10)
    )
    ### THE END OF YOUR CODE ###

  def forward(self, x, lens):
    # разбейте сигнал на окна 
    # batch_windows.shape == (B, NUM WINDOWS, 1024)
    batch_windows = x.unfold(1, self.window_length, self.hop_length)  #your code here


    # примените к каждому окну полносвязную сеть
    # batch_windows_feautures.shape == (B, NUM WINDOWS, 16)
    batch_windows_feautures = self.first_mlp(batch_windows) #your code here

    # примените к получившемся последовательностям LSTM и возьмите hidden state
    output, (hs, cs) = self.rnn(batch_windows_feautures)

    # склейте hidden_state по слоям
    # hidden_flattened.shape = (B, 2 * hidden_size * num_layers)
    hidden_flattened = torch.cat([hs[0], hs[1], hs[2], hs[3]], dim=1) #your code here

    # примените полносвязную сеть и получим логиты классов
    return self.final_mlp(hidden_flattened) #your code here

# %% [markdown]
# Обучим получившуюся модель.

# %%
from IPython.display import clear_output

def train_audio_clfr(model, optimizer, train_dataloader, sr,
                     criterion=torch.nn.CrossEntropyLoss(),
                     data_transform=None, 
                     augmentation=None,
                     num_epochs=10, device='cuda:0',
                     verbose_num_iters=10):
  model.train()
  iter_i = 0

  train_losses = []
  train_accuracies = []

  for epoch in range(num_epochs):  
    for batch in train_dataloader:
        x = batch['x'].to(device)
        y = batch['y'].to(device)
        lens = batch['len'].to(device)
        
        # применяем преобразование входных данных
        if data_transform:
          x, lens = data_transform(x,
                                   lens, 
                                   device=device, 
                                   sr=sr)

        # примеменяем к логмелспектрограмме аугментацию
        if augmentation:
          x, lens = augmentation(x, lens)

        # делаем предсказания
        probs = model(x, lens)

        # делаем шаг градиента
        optimizer.zero_grad()
        loss = criterion(probs, y)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())
        
        # считаем точность предсказания
        pred_cls = probs.argmax(dim=-1)
        train_accuracies.append((pred_cls == y).float().mean().item())
    
        iter_i += 1

        # раз в verbose_num_iters визуализируем наши лоссы и семплы
        if iter_i % verbose_num_iters == 0:
            clear_output(wait=True)

            print(f'Epoch {epoch}')

            plt.figure(figsize=(10, 5))
                
            plt.subplot(1, 2, 1)
            plt.xlabel('Iteration')
            plt.ylabel('Train loss')
            plt.plot(np.arange(iter_i), train_losses)

            plt.subplot(1, 2, 2)
            plt.xlabel('Iteration')
            plt.ylabel('Train acc')
            plt.plot(np.arange(iter_i), train_accuracies)

            plt.show()

  model.eval()

# %%
# создадим объекты модели и оптимизатор
rnn_raw = RecurrentRawAudioClassifier()
rnn_raw.to(device);

optim = torch.optim.Adam(rnn_raw.parameters(), lr=3e-4)

# %%
# обучим модель
train_audio_clfr(rnn_raw, optim, train_dataloader, train_dataset.sr)
# Out:
# Epoch 9

# %% [markdown]
# Посчитаем метрики на валидационном датасете.

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(model, val_dataloader, sr, device, data_transform=None):
  pred_true_pairs = []
  for batch in val_dataloader:
        x = batch['x'].to(device)
        y = batch['y'].to(device)
        lens = batch['len'].to(device)
        
        with torch.no_grad():
          if data_transform:
            x, lens = data_transform(x, lens, sr=sr, device=device)

          probs = model(x, lens)

          pred_cls = probs.argmax(dim=-1)

        for pred, true in zip(pred_cls.cpu().detach().numpy(), y.cpu().numpy()):
          pred_true_pairs.append((pred, true))

  print(f'Val accuracy: {np.mean([p[0] == p[1] for p in pred_true_pairs])}')

  cm_df = pd.DataFrame(
      confusion_matrix([p[1] for p in pred_true_pairs], 
                       [p[0] for p in pred_true_pairs], 
                       normalize='true'),
      columns=classes, index=classes)
  sn.heatmap(cm_df, annot=True)

# %%
plot_confusion_matrix(rnn_raw, val_dataloader, train_dataset.sr, device)
# Out:
# Val accuracy: 0.3657754010695187

# %% [markdown]
# *Вопрос* : Сильно ли отличается качество модели на тренировочной и валидационной выборке? Если да, то как думаете, в чем причина?

# %% [markdown]
# ## Задание 3. Построение Мел-cпектрограмм. (2 балла)
#
# Сырой сигнал очень чувствителен ко многим факторам - увеличение/уменьшение громкости, внешние шумы, сменение тембра говорящего очень резко меняют сырой сигнал. Это влияет и на качество глубоких сетей, обученных на сыром аудиосигнале.
#
# Для построения надежных и устойчивых к переобучению моделей используют другое представление аудиоданных - спектрограммы, в том числе Мел-спектрограмму.
#
# Идея её построения заключается в следующем:
# 1. Сигнал разбивается на временные интервалы (с пересечениями)
# 2. К каждому временному интервалу применяется фильтр (как правило косинусоидальный)
# 3. К профильтрованному сигналу применяется дискретное преобразование Фурье и вычисляются спектральные признаки сигнала.
# 4. Спектральные признаки с помощью логарифмического преобразования приводятся в Мел-шкалу.
#
# ![image](https://antkillerfarm.github.io/images/img2/Spectrogram_5.png)
#
# В этом задании мы сами шаг за шагом напишем алгоритм построения мелспектрограммы и сравнимся с референсной функцией из `torchaudio`.

# %%
from torchaudio.transforms import MelSpectrogram

# референсная функця
def compute_log_melspectrogram_reference(wav_batch, 
                                         lens,
                                         sr,
                                         device='cpu'):
  featurizer = MelSpectrogram(
      sample_rate=sr,
      n_fft=1024,
      win_length=1024,
      hop_length=256,
      n_mels=64,
      center=False,
      ).to(device)

  return torch.log(featurizer(wav_batch).clamp(1e-5)), lens // 256

# %%
# возьмем случайный батч
for batch in train_dataloader:
  break
wav_batch = batch['x']
lens = batch['len']

# посчитаем лог мелспектрограммы
log_melspect, lens = compute_log_melspectrogram_reference(wav_batch, lens, train_dataset.sr)

# нарисуем получившиеся референсные значения
fig, axes = plt.subplots(5, figsize=(16, 8))

for i in range(5):
  axes[i].axis('off')
  axes[i].set_title(f'Reference log melspectorgram {i}')
  axes[i].imshow(log_melspect[i].numpy())

# %% [markdown]
# Теперь сделаем то же самое сами.

# %%
sr = train_dataset.sr
n_fft=1024
win_length=1024
hop_length=256
n_mels=64

# %% [markdown]
# Для начала с помощью метода `unfold` разделим аудиосигнал на окна размера `win_lenght` через промежутки `hop_lenght`.

# %%
windows = wav_batch.unfold(1, win_length, hop_length) # your code here
assert windows.shape == (32, 1497, 1024)

# %% [markdown]
# Нарисуем и проиграем сигнал из одного окна.

# %%
plt.figure(figsize=(16, 8))
plt.plot(windows[0, 0])

display.Audio(windows[0, 0], rate=train_dataset.sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Теперь нам надо применить косинуисальный фильтр к сигналу из окна. Для этого с помощью `torch.hann_window` создадим косинусоидальный фильтр и умножим его поэлементно на все окна.

# %%
filter = torch.hann_window(win_length) # your code here
windows_with_applied_filter = windows * filter[None, None, :]

# %%
plt.figure(figsize=(16, 8))
plt.plot(windows_with_applied_filter[0, 0])

display.Audio(windows_with_applied_filter[0, 0], rate=train_dataset.sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# С помощью `torch.fft.fft` примените дискретное преобразование фурье к каждому окну и возьмите первые `n_fft // 2 + 1` компоненты.
#
# Дальше с помощью возведения элементов тензора в квадрат и `torch.abs()` получите магнитуды.

# %%
fft_features = torch.fft.fft(windows_with_applied_filter)[:, :, :(n_fft // 2 + 1)] # your code here
fft_magnitudes = torch.abs(fft_features ** 2)
assert fft_magnitudes.shape == (32, 1497, 513)

# %% [markdown]
# Через `torchaudio.transforms.MelScale` создайте класс для перевода магнитуд в Мел-шкалу.

# %%
melscale = torchaudio.transforms.MelScale(sample_rate=sr,
      n_mels=64
      )
magnitudes_transposed = torch.transpose(fft_magnitudes, dim0=1, dim1=2)
melscale(magnitudes_transposed)
# Out:
# tensor([[[5.5121e+01, 7.7947e+01, 3.7210e+01,  ..., 2.1675e+01,
#           1.3751e+01, 7.3278e+00],
#          [1.9927e+01, 1.6681e+01, 9.8770e+00,  ..., 1.3430e+01,
#           7.2090e+00, 1.6586e+00],
#          [4.0588e+00, 1.5608e+00, 1.6448e+00,  ..., 3.6436e+00,
#           3.5837e+00, 1.0011e+00],
#          ...,
#          [5.0954e-03, 6.4442e-03, 8.6215e-03,  ..., 5.6545e-03,
#           7.0050e-03, 6.3268e-03],
#          [1.6471e-02, 2.2227e-02, 1.7667e-02,  ..., 1.0496e-02,
#           1.2125e-02, 1.5562e-02],
#          [3.4795e-02, 2.7973e-02, 2.0992e-02,  ..., 1.7432e-02,
#           2.1106e-02, 1.9714e-02]],
#
#         [[8.8407e-01, 4.4277e-01, 1.0382e-02,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [3.6752e+00, 3.7256e+00, 1.7397e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [4.5071e+00, 4.5423e+00, 1.7364e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [1.6458e-05, 1.5134e-05, 1.8153e-05,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.4512e-05, 1.3581e-05, 1.3649e-05,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.4062e-05, 1.5042e-05, 1.2239e-05,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00]],
#
#         [[9.8389e+00, 2.6154e+01, 2.8975e+01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [4.3172e+00, 7.5616e+01, 1.0672e+02,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.4725e+01, 8.2708e+01, 9.2897e+01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [1.1163e-01, 2.1854e-01, 1.0466e-01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.9359e-02, 2.3166e-02, 2.2361e-02,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.2582e-02, 1.4819e-02, 8.1059e-03,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00]],
#
#         ...,
#
#         [[2.0546e+03, 1.4549e+03, 6.5803e+02,  ..., 3.5872e+01,
#           5.0989e+02, 1.1210e+03],
#          [9.9230e+02, 1.0001e+03, 5.5081e+02,  ..., 1.9563e+02,
#           7.3428e+02, 6.0473e+02],
#          [1.7635e+02, 2.4513e+02, 2.0831e+02,  ..., 1.9135e+02,
#           3.7548e+02, 1.1362e+02],
#          ...,
#          [2.3999e-04, 2.1992e-04, 2.5047e-04,  ..., 4.4206e-04,
#           4.2885e-04, 4.8260e-04],
#          [3.1726e-04, 2.6530e-04, 2.4950e-04,  ..., 9.0028e-04,
#           6.3549e-04, 6.8979e-04],
#          [2.6563e-04, 2.7183e-04, 2.3199e-04,  ..., 8.1419e-04,
#           7.1105e-04, 5.4520e-04]],
#
#         [[3.2537e-01, 7.2327e-01, 2.6852e-01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [6.7496e-01, 1.2140e+00, 1.0735e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [5.8155e-01, 9.5760e-01, 8.8925e-01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [1.1699e-03, 6.7171e-04, 6.0931e-03,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.0676e-03, 4.9068e-04, 5.0085e-03,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [9.2273e-04, 2.3773e-04, 3.0332e-03,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00]],
#
#         [[6.9070e+01, 9.7634e+01, 8.5411e+01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [2.4379e+02, 2.0079e+02, 1.6696e+02,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.2982e+02, 6.5346e+01, 5.1141e+01,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [1.0505e-03, 1.3117e-03, 1.3668e-03,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [7.8300e-04, 9.1917e-04, 8.7301e-04,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [6.9462e-04, 6.4273e-04, 6.0034e-04,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00]]])

# %% [markdown]
# Нелинейное преобразование для перевода в Мел-шкалу выглядит следующим образом.

# %%
plt.figure(figsize=(10, 5))
plt.axis('off')
plt.imshow(melscale.fb.numpy().transpose())

# %% [markdown]
# Примените Мел-шкалу к магнитудам.

# %%
mel_spectrogram = melscale(magnitudes_transposed) # your code here
assert mel_spectrogram.shape == (32, 64, 1497)

# %% [markdown]
# Сделайте обрезку значений по `1e-5` и примените `torch.log` для получения логарифмированной Мел-спектрограммы.

# %%
logmel_spectrogram = torch.log(mel_spectrogram.clamp(1e-5)) # your code here
assert logmel_spectrogram.shape == (32, 64, 1497)

# %% [markdown]
# Полученные логарифмированные Мел-Спектрограммы должны совпадать с референсными.

# %%
# нарисуем получившиеся значения
fig, axes = plt.subplots(5, figsize=(16, 8))

for i in range(5):
  axes[i].axis('off')
  axes[i].set_title(f'Your log melspectorgram {i}')
  axes[i].imshow(logmel_spectrogram[i].numpy())

# %% [markdown]
# Теперь оформим эту логику в функцию.

# %%
# ваша реализация
def compute_log_melspectrogram(wav_batch,
                               lens,
                               sr,
                               device='cpu'):
  ### YOUR CODE IS HERE ######

  windows = wav_batch.unfold(1, 1024, 256).to(device)
  filter = torch.hann_window(win_length).to(device)
  windows_with_applied_filter = windows * filter[None, None, :]

  fft_features = torch.fft.fft(windows_with_applied_filter)[:, :, :n_fft // 2 + 1].to(device)
  fft_magnitudes = torch.abs(fft_features ** 2).to(device)

  magnitudes_transposed = torch.transpose(fft_magnitudes, dim0=1, dim1=2).to(device)
  melscale = torchaudio.transforms.MelScale(sample_rate=sr, n_mels=64).to(device)
  
  mel_spectrogram = melscale(magnitudes_transposed).to(device) 
  logmel_spectrogram = torch.log(mel_spectrogram.clamp(1e-5)).to(device)

  return logmel_spectrogram, lens // 256
  ### THE END OF YOUR CODE ###

# %% [markdown]
# Финальная проверка.

# %%
assert torch.allclose(
    compute_log_melspectrogram_reference(wav_batch, lens, train_dataset.sr)[0],
    compute_log_melspectrogram(wav_batch, lens, train_dataset.sr)[0],
    atol=1e-5)

# %% [markdown]
# ## Задание 4. Рекуррентная сеть для классификации аудиозаписей по логарифмированным Мел-спектрограммам (1 балл)
#
# Измените реализацию рекуррентной сети из задания 2, таким образом, чтобы она вместо сырого сигнала смогла принимать логарифмированные Мел-спетрограммы:
# 1. Уберите шаги 1-2
# 2. Сделайте вход LSTM равным 64
#
# ![arch_mel](https://github.com/hse-ds/iad-applied-ds/blob/master/2021/hw/hw2/imgs/rnn_mel.png?raw=1)
#
# **За реализацию архитектуры дается 0.5 балла.**

# %%
class RecurrentMelSpectClassifier(nn.Module):
  def __init__(self, 
               num_classes=10,
               window_length=1024,
               hop_length=256,
               hidden=256,
               num_layers=2):
    super().__init__()

    self.window_length = window_length
    self.hop_length = hop_length

    ### YOUR CODE IS HERE ######
    self.rnn = nn.LSTM(64, hidden, num_layers, bidirectional=True, batch_first=True)

    self.final_mlp = nn.Sequential(
        nn.Linear(2 * hidden * num_layers, 256),
        nn.BatchNorm1d(256),
        nn.ReLU(),
        nn.Linear(256, 10)
    )
    ### THE END OF YOUR CODE ###

  def forward(self, x, lens):
   ### YOUR CODE IS HERE ###### 
    output, (hs, cs) = self.rnn(x)

    # склейте hidden_state по слоям
    # hidden_flattened.shape = (B, 2 * hidden_size * num_layers)
    hidden_flattened = torch.cat([hs[0], hs[1], hs[2], hs[3]], dim=1) #your code here

    # примените полносвязную сеть и получим логиты классов
    return self.final_mlp(hidden_flattened) #your code here
   ### THE END OF YOUR CODE ###

# %%
rnn_mel = RecurrentMelSpectClassifier()
rnn_mel.to(device);

optim = torch.optim.Adam(rnn_mel.parameters(), lr=3e-4)

# %%
def compute_log_melspectrogram_for_lstm(wav_batch,
                               lens,
                               sr,
                               device='cpu'):
  # чтобы избежать проблем с размерностями, немного видоизменим функцию из предыдущего задания

  windows = wav_batch.unfold(1, 1024, 256).to(device)
  filter = torch.hann_window(win_length).to(device)
  windows_with_applied_filter = windows * filter[None, None, :]

  fft_features = torch.fft.fft(windows_with_applied_filter)[:, :, :n_fft // 2 + 1].to(device)
  fft_magnitudes = torch.abs(fft_features ** 2).to(device)

  magnitudes_transposed = torch.transpose(fft_magnitudes, dim0=1, dim1=2).to(device)
  melscale = torchaudio.transforms.MelScale(sample_rate=sr, n_mels=64).to(device)
  
  mel_spectrogram = melscale(magnitudes_transposed).to(device) 
  logmel_spectrogram = torch.log(mel_spectrogram.clamp(1e-5)).to(device)

  return torch.transpose(logmel_spectrogram, dim0=1, dim1=2), lens // 256

# %%
train_audio_clfr(rnn_mel, optim, train_dataloader, train_dataset.sr, 
                 data_transform=compute_log_melspectrogram_for_lstm)
# Out:
# Epoch 9

# %% [markdown]
# Посчитаем метрики на валидационном датасете.

# %% [markdown]
# **Задание: для получения 0.5 балла сделайте подбор гиперпараметров и добейтесь accuracy модели выше 0.8 на валидационном датасете.**

# %%
plot_confusion_matrix(rnn_mel, val_dataloader, train_dataset.sr, device, 
                      data_transform=compute_log_melspectrogram_for_lstm)
# Out:
# Val accuracy: 0.8299465240641711

# %% [markdown]
# ## Задание 5. Cверточная сеть для классификации аудиозаписей по мелспектрограммам. (2 балла)
#
# Легко заметить, что мелспектрограммы имеют четко выраженные паттерны - если приноровиться, то даже человек, посмотрев на мелспектрограмму, сможет _визуально_ проклассифицировать объект.
#
# Это позволяет свести задачу классификации аудиозаписей к задаче классификации картинок.
#
# Реализуем такую сверточную сеть:
#
# * 2x (Conv2d 3x3 @ 16, BatchNorm2d, ReLU)
# * MaxPoll 2x2
# * 2x (Conv2d 3x3 @ 32, BatchNorm2d, ReLU)
# * MaxPoll 2x2
# * 2x (Conv2d 3x3 @ 64, BatchNorm2d, ReLU)
# * MaxPoll 2x2
# * (Conv2d 3x3 @ 128, BatchNorm2d, ReLU)
# * (Conv2d 2x2 @ 128, BatchNorm2d, ReLU)
# * Global MaxPoll
# * Fully Connected 128, ReLU
# * Fully Connected 10
#
# Совет: подобная архитектура была реализована в [**PANNs: Large-Scale Pretrained Audio Neural Networks for Audio Pattern Recognition**](https://arxiv.org/pdf/1912.10211.pdf), можете использовать эту статью как референс.
#
#
# **За реализацию архитектуры дается 1.5 балла.**

# %%
class CNN10(nn.Module):
  def __init__(self, num_classes=10, hidden=16):
    super().__init__()

    ### YOUR CODE IS HERE ######
    self.cnn_backbone = nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.BatchNorm2d(16),
        nn.ReLU(),
        nn.Conv2d(16, 16, 3),
        nn.BatchNorm2d(16),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(16, 32, 3),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.Conv2d(32, 32, 3),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(32, 64, 3),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.Conv2d(64, 64, 3),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(64, 128, 3),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.Conv2d(128, 128, 2),
        nn.BatchNorm2d(128),
        nn.ReLU()
    )

    self.final_mlp = nn.Sequential( 
        nn.Linear(128, 128),
        nn.ReLU(),
        nn.Linear(128, 10)
    )
    ### THE END OF YOUR CODE ###

  def forward(self, x, lens):
    z = self.cnn_backbone(x[:, None, :, :])
    z = torch.nn.functional.max_pool2d(z, kernel_size=z.size()[2:])[:, :, 0, 0]
    return self.final_mlp(z)

# %%
cnn = CNN10()
cnn.to(device);

optim = torch.optim.Adam(cnn.parameters(), lr=3e-4)

# %%
train_audio_clfr(cnn, optim, train_dataloader, train_dataset.sr, 
                 data_transform=compute_log_melspectrogram_for_lstm,
                 num_epochs=20)
# Out:
# Epoch 19

# %% [markdown]
# **Задание: для получения 0.5 балла сделайте подбор гиперпараметров и добейтесь accuracy модели выше 0.85 на валидационном датасете.**

# %%
plot_confusion_matrix(cnn, val_dataloader, train_dataset.sr, device, 
                      data_transform=compute_log_melspectrogram_for_lstm)
# Out:
# Val accuracy: 0.9026737967914439

# %% [markdown]
# ## Задание 6. Аугментация SpecAugment (2 балла)
#
# Обычно датасеты с аудиозаписями довольно малы. Наш датасет тому пример - всего 4500 объектов в обучающей выборке. Обучение глубокий сетей с большим кол-вом параметров на таких датасетах часто ведет к переобучению и проседанию метрик на валидационном и тестовом датасетах.
#
# Для борьбы с переобучением имеет смысл использовать аугментацию данных. Для мелспектрограмм была придумана аугментация под названием SpecAugment.
#
# Смысл её очень прост - зануление спектрограммы по временным промежуткам и по мел-частотам:
# 1. Выбираются несколько временных промежутков ${[t^1_i, t^2_i]}$ и заполняют спектрограмму $s[t^1_i : t^2_i, :]$ значением $v$.
#
# 2. Выбираются несколько промежутков мелчастот ${[m^1_i, m^2_i]}$ и заполняют спектрограмму $s[:, m^1_i : m^2_i]$ значением $v$.
#
# В качестве значения $v$ выбирают:
# 1. `'mean'`: среднее по спектрограмме
# 2. `'min'`: минимум по спектрограмме
# 3. `'max'`: максимум по спектрограмме
# 5. `v`: некоторая константа
#
# Совет: описание аугментации можно найти здесь: [link](https://neurohive.io/ru/novosti/specaugment-novyj-metod-augmentacii-audiodannyh-ot-google-ai/), можете использовать эту ссылку как референс.
#
# ![specaugment](https://neurohive.io/wp-content/uploads/2019/04/image6.png)
#
# В этом задании Вам предлагается реализовать аугментацию SpecAugment.
#
# **За реализацию аугментации дается 1.5 балла.**

# %%
import numpy as np


class SpectAugment:
    def __init__(
        self,
        filling_value = 'mean',
        n_freq_masks = 2,
        n_time_masks = 2,
        max_freq = 10,
        max_time = 50,
    ):

        self.filling_value = filling_value
        self.n_freq_masks = n_freq_masks
        self.n_time_masks = n_time_masks
        self.max_freq = max_freq
        self.max_time = max_time

    def __call__(self, spect, lens):
        ### YOUR CODE IS HERE ######
        m = np.sort(np.random.randint(0, self.max_freq, size=2*self.n_freq_masks))
        t = np.sort(np.random.randint(0, self.max_time, size=2*self.n_time_masks))
        
        if self.filling_value == 'mean': v = spect.mean(axis=2).mean(axis=1)
        elif self.filling_value == 'max': v = spect.max(axis=2).values.max(axis=1).values
        elif self.filling_value == 'min': v = spect.min(axis=2).values.min(axis=1).values

        spect_t = torch.transpose(spect, 0, 1)

        for i in range(self.n_freq_masks):
          spect_t[:, :, m[i*2] : m[i*2 + 1]] = v[:, None]
        for j in range(self.n_time_masks):
          spect_t[t[j*2] : t[j*2 + 1], :, :] = v[:, None]
        
        return torch.transpose(spect_t, 0, 1), lens // 256
        ### THE END OF YOUR CODE ###

# %%
# применим аугментацию к данным
for batch in train_dataloader:
  break

x = batch['x'].to(device)
lens = batch['len'].to(device)
x_logmel, lens = compute_log_melspectrogram_reference(x, lens, sr=train_dataset.sr, device=device)

# нарисуем спектрограмму до и после аугментации
plt.figure(figsize=(20, 5))
plt.subplot(2, 1, 1)
plt.title('Original log MelSpectrogram')
plt.axis('off')
plt.imshow(x_logmel[0].cpu().numpy())

x_logmel_augmented, lens = SpectAugment()(x_logmel, lens)
plt.figure(figsize=(20, 5))
plt.subplot(2, 1, 2)
plt.title('Augmented log MelSpectrogram')
plt.axis('off')
plt.imshow(x_logmel_augmented[0].cpu().numpy())

# %%
cnn = CNN10()
cnn.to(device);

optim = torch.optim.Adam(cnn.parameters(), lr=3e-4)

# %%
# обучим модель на данных с аугментациями
train_audio_clfr(cnn, optim, train_dataloader, train_dataset.sr, 
                 data_transform=compute_log_melspectrogram_for_lstm,
                 augmentation=SpectAugment(filling_value = 'mean',
                                           n_freq_masks = 3,
                                           n_time_masks = 1,
                                           max_freq = 10,
                                           max_time = 75),
                 num_epochs=20)
# Out:
# Epoch 19

# %% [markdown]
# **Задание: для получения 0.5 балла сделайте подбор параметров аугментации и добейтесь accuracy модели выше 0.9 на валидационном датасете.**

# %%
plot_confusion_matrix(cnn, val_dataloader, train_dataset.sr, device, 
                      data_transform=compute_log_melspectrogram_for_lstm)
# Out:
# Val accuracy: 0.9219251336898395
